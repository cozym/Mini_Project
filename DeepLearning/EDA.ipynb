# %% [markdown]
# #**스마트폰 센서 데이터 기반 모션 분류**
# # 단계1 : 탐색적 데이터 분석

# %% [markdown]
# ## 0.미션

# %% [markdown]
# ### (1) 미션1
# 수많은 feature들을 모두 살펴보는 것은 과도한 시간과 노력이 필요합니다. 그래서 여러분은 **선택과 집중**을 해야 합니다.
# * 1) **기본 모델을 생성**한 후 **변수 중요도**를 구합니다.
#     * random forest 알고리즘 사용을 권장합니다.
# * 2) **중요한 feature와 중요하지 않은 feature 상위 N개를 선정**하고, 이들을 대상으로 EDA 수행.

# %% [markdown]
# ### (2) 미션2
# 다음의 case에 맞게 feature 및 feature 그룹 중요도를 기반으로 탐색적 데이터 분석을 수행하시오.
# * Target을 **정적/동적 행동**으로 구분
#     * 6개의 행동은 2개의 그룹(정적행동, 동적행동)으로 나뉩니다.
#     * 어떤 feature(혹은 feature 그룹)이 2개 class 그룹(정적행동, 동적행동)를 구분하는데 중요한지를 찾아보고 탐색해봅시다.

# %% [markdown]
# ## 1.환경설정

# %% [markdown]
# * 세부 요구사항
#     - 경로 설정 : 구글콜랩
#         * 구글 드라이브 바로 밑에 project3 폴더를 만들고,
#         * 데이터 파일을 복사해 넣습니다.
#     - 기본적으로 필요한 라이브러리를 import 하도록 코드가 작성되어 있습니다.
#         * 필요하다고 판단되는 라이브러리를 추가하세요.

# %% [markdown]
# ### (1) 경로 설정

# %% [markdown]
# * 구글 드라이브 연결

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/mini_project3/'

# %% [markdown]
# ### (2) 라이브러리 설치 및 불러오기

# %% [markdown]
# * 라이브러리 로딩

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import joblib

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix

# %% [markdown]
# * 제공 함수 생성
#     * 변수 중요도를 시각화할 수 있는 함수를 제공합니다.
#     * 입력 :
#         * importance : 트리모델의 변수 중요도(예: model.feature_importances_)
#         * names : 변수 이름 목록(예 : x_train.columns
#         * result_only  : 변수 중요도 순으로 데이터프레임만 return할지, 그래프도 포함할지 결정. False이면 결과 데이터프레임 + 그래프
#         * topn : 중요도 상위 n개만 표시. all 이면 전체.
#     * 출력 :
#         * 중요도 그래프 : 중요도 내림차순으로 정렬
#         * 중요도 데이터프레임 : 중요도 내림차순으로 정렬

# %%
# 변수의 특성 중요도 계산하기
def plot_feature_importance(importance, names, result_only = False, topn = 'all'):
    feature_importance = np.array(importance)
    feature_name = np.array(names)

    data={'feature_name':feature_name,'feature_importance':feature_importance}
    fi_temp = pd.DataFrame(data)

    #변수의 특성 중요도 순으로 정렬하기
    fi_temp.sort_values(by=['feature_importance'], ascending=False,inplace=True)
    fi_temp.reset_index(drop=True, inplace = True)

    if topn == 'all' :
        fi_df = fi_temp.copy()
    else :
        fi_df = fi_temp.iloc[:topn]

    #변수의 특성 중요도 그래프로 그리기
    if result_only == False :
        plt.figure(figsize=(10,20))
        sns.barplot(x='feature_importance', y='feature_name', data = fi_df)

        plt.xlabel('importance')
        plt.ylabel('feature name')
        plt.grid()

    return fi_df

# %% [markdown]
# ### (3) 데이터 불러오기

# %% [markdown]
# * 주어진 데이터셋
#     * data01_train.csv : 학습 및 검증용
#     * data01_test.csv : 테스트용
#     * feature.csv : feature 이름을 계층구조로 정리한 데이터
#
# * 세부 요구사항
#     * 칼럼 삭제 : data01_train.csv와 data01_test.csv 에서 'subject' 칼럼은 불필요하므로 삭제합니다.

# %%
data_train = pd.read_csv(path + 'data01_train.csv')
data_test = pd.read_csv(path + 'data01_test.csv')
features = pd.read_csv(path + 'features.csv')

# %%
data_train.drop(columns=['subject'], inplace=True)
data_test.drop(columns=['subject'], inplace=True)

# %% [markdown]
# ## 2.데이터 분석 : 기본정보 살펴보기

# %% [markdown]
# ### (1) 기본정보 확인하기

# %% [markdown]
# * **세부 요구사항**
#     - 불러온 데이터의 형태, 기초통계량, 정보 등을 확인합니다.

# %%
data_train.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288508          -0.009196          -0.103362         -0.988986
# 1           0.265757          -0.016576          -0.098163         -0.989551
# 2           0.278709          -0.014511          -0.108717         -0.997720
# 3           0.289795          -0.035536          -0.150354         -0.231727
# 4           0.394807           0.034098           0.091229          0.088489
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.962797         -0.967422         -0.989000         -0.962596
# 1         -0.994636         -0.987435         -0.990189         -0.993870
# 2         -0.981088         -0.994008         -0.997934         -0.982187
# 3         -0.006412         -0.338117         -0.273557          0.014245
# 4         -0.106636         -0.388502         -0.010469         -0.109680
#
# ...

# %%
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5881 entries, 0 to 5880
# Columns: 562 entries, tBodyAcc-mean()-X to Activity
# dtypes: float64(561), object(1)
# memory usage: 25.2+ MB

# %%
data_train.shape
data_train.describe()
# Out:
#        tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# count        5881.000000        5881.000000        5881.000000
# mean            0.274811          -0.017799          -0.109396
# std             0.067614           0.039422           0.058373
# min            -0.503823          -0.684893          -1.000000
# 25%             0.262919          -0.024877          -0.121051
# 50%             0.277154          -0.017221          -0.108781
# 75%             0.288526          -0.010920          -0.098163
# max             1.000000           1.000000           1.000000
#
#        tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# count       5881.000000       5881.000000       5881.000000       5881.000000
# mean          -0.603138         -0.509815         -0.604058         -0.628151
# std            0.448807          0.501815          0.417319          0.424345
# min           -1.000000         -0.999844         -0.999667         -1.000000
# ...

# %%
data_test.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.284379          -0.021981          -0.116683         -0.992490
# 1           0.277440          -0.028086          -0.118412         -0.996620
# 2           0.305833          -0.041023          -0.087303          0.006880
# 3           0.276053          -0.016487          -0.108381         -0.995379
# 4           0.271998           0.016904          -0.078856         -0.973468
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.979640         -0.963321         -0.992563         -0.977304
# 1         -0.927676         -0.972294         -0.997346         -0.931405
# 2          0.182800         -0.237984          0.005642          0.028616
# 3         -0.983978         -0.975854         -0.995877         -0.985280
# 4         -0.702462         -0.869450         -0.979810         -0.711601
#
# ...

# %%
features.head()
# Out:
#      sensor     agg axis       feature_name
# 0  tBodyAcc  mean()    X  tBodyAcc-mean()-X
# 1  tBodyAcc  mean()    Y  tBodyAcc-mean()-Y
# 2  tBodyAcc  mean()    Z  tBodyAcc-mean()-Z
# 3  tBodyAcc   std()    X   tBodyAcc-std()-X
# 4  tBodyAcc   std()    Y   tBodyAcc-std()-Y

# %%
features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 561 entries, 0 to 560
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sensor        561 non-null    object
#  1   agg           561 non-null    object
#  2   axis          436 non-null    object
#  3   feature_name  561 non-null    object
# dtypes: object(4)
# memory usage: 17.7+ KB

# %% [markdown]
# ### (2) 목표 변수 확인하기

# %% [markdown]
# * **세부 요구사항**
#     - target인 'Activity'에 대해 단변량 분석을 수행합니다.
#     - 범주의 종류, 범주별 빈도수 및 비율 등

# %%
target = 'Activity'

# %%
data_train[target].value_counts()
# Out:
# Activity
# LAYING                1115
# STANDING              1087
# SITTING               1032
# WALKING                998
# WALKING_UPSTAIRS       858
# WALKING_DOWNSTAIRS     791
# Name: count, dtype: int64

# %%
data_train[target].value_counts(normalize=True)
# Out:
# Activity
# LAYING                0.189594
# STANDING              0.184833
# SITTING               0.175480
# WALKING               0.169699
# WALKING_UPSTAIRS      0.145894
# WALKING_DOWNSTAIRS    0.134501
# Name: proportion, dtype: float64

# %%
sns.countplot(x = target, data=data_train)
plt.xticks(rotation=45)
plt.grid()
plt.show()

# %% [markdown]
# ## 3.미션1 : 데이터 분석1

# %% [markdown]
# 수많은 feature들을 모두 살펴보는 것은 과도한 시간과 노력이 필요합니다. 그래서 여러분은 **선택과 집중**을 해야 합니다.
# * 1) **트리 모델을 생성**한 후 **변수 중요도**를 구합니다.
#     * random forest 알고리즘 사용을 권장합니다.
# * 2) **중요한 feature 상위 N개를 선정**하고, 이들을 대상으로 EDA 수행.
# * 3) **각 feature 그룹별 중요도**도 파악해보며 EDA를 수행
#     * Feature 이름에는 계층구조를 담고 있습니다. 그렇다 보니 feature들을 적절하게 그룹으로 묶을 수 있습니다.
#     * 참고로, feature 그룹의 중요도는 개별 feature 중요도의 합으로 계산할 수 있습니다.

# %% [markdown]
# ### (1) 기본모델링 + 변수중요도 추출

# %% [markdown]
# * **세부 요구사항**
#     - 모델링을 위한 기본 전처리를 수행합니다.
#         - 주어진 데이터에서는 x, y로 나누고 train과 validation 분할 수행
#     - 트리기반 알고리즘을 이용하여 모델링을 합니다.
#         - 랜덤포레스트 권장 : 랜덤포레스트는 튜닝 없이 하이퍼파리미터의 기본값로도 적절한 성능의 모델을 생성할 수 있습니다.
#     - 변수 중요도 추출
#         - 사용자정의함수로 생성한 plot_feature_importance 을 이용
#         - 변수중요도 파악및 결과 저장

# %% [markdown]
# #### 1) 데이터 전처리

# %%
x = data_train.drop(columns=target)
y = data_train[target]

# %%
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=0.2, random_state=20)

# %%
scaler = MinMaxScaler()
x_train_s = scaler.fit_transform(x_train)
x_val_s = scaler.transform(x_val)

# %% [markdown]
# #### 2) 모델링

# %%
model_RF = RandomForestClassifier(max_depth=5, random_state=20)

# %%
model_RF.fit(x_train, y_train)
# Out:
# RandomForestClassifier(max_depth=5, random_state=20)

# %%
pred = model_RF.predict(x_val)

# %%
print(classification_report(y_val, pred))
# Out:
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       202
#            SITTING       0.94      0.89      0.91       211
#           STANDING       0.89      0.94      0.92       214
#            WALKING       0.91      0.95      0.93       203
# WALKING_DOWNSTAIRS       0.94      0.88      0.91       170
#   WALKING_UPSTAIRS       0.92      0.93      0.93       177
#
#           accuracy                           0.93      1177
#          macro avg       0.93      0.93      0.93      1177
#       weighted avg       0.93      0.93      0.93      1177

# %% [markdown]
# #### 3) 변수 중요도 추출

# %%
print(list(model_RF.feature_importances_))
# Out:
# [4.216950588625901e-05, 0.0003147866896153307, 0.0, 0.0016330525853515516, 4.3186398978948054e-05, 0.00043067481459562, 0.003130967418011703, 9.017843812108884e-05, 0.00018943554687585035, 0.014164890009377333, 1.6757896437613087e-05, 2.27174723600423e-05, 0.0001489180769989823, 0.0, 1.1230785367800183e-05, 0.0002842331798884071, 0.001527326772234805, 0.00023050961399146967, 0.00037657433499523984, 0.0007355169619921825, 9.210503235062409e-05, 0.0, 0.0007591075403013538, 2.228126288118512e-05, 1.64159897558289e-05, 0.0007961530310652369, 1.4872697016434205e-05, 0.0, 0.00010048321450890658, 7.5822295907789815e-06, 0.0, 0.0, 0.0, 0.0, 1.4125476948198956e-05, 1.8406107106466257e-05, 2.1713053232176124e-05, 0.005474429637539603, 0.0010427524182232554, 0.0031897518707088286, 0.029902738865261392, 0.026350922797917717, 0.010767033575060956, 0.0008239434111444385, 0.0006889750798743753, 0.00012066056951360031, 0.0015496642695343992, 0.000442615843097535, 0.0010456407215145946, 0.03038318244
# ...

# %%
df1 = plot_feature_importance(model_RF.feature_importances_, x_train.columns, result_only=True)

# %%
df1.loc[df1['feature_importance'] > 0.01]
# Out:
#                        feature_name  feature_importance
# 0               tGravityAcc-min()-X            0.040424
# 1            tGravityAcc-energy()-X            0.033286
# 2              angle(X,gravityMean)            0.031455
# 3               tGravityAcc-max()-X            0.030383
# 4              tGravityAcc-mean()-X            0.029903
# 5              tGravityAcc-mean()-Y            0.026351
# 6            tGravityAcc-energy()-Y            0.024172
# 7               tGravityAcc-min()-Y            0.022964
# 8               tGravityAcc-max()-Y            0.021267
# 9          tBodyAccJerkMag-energy()            0.019751
# 10  fBodyAccJerk-bandsEnergy()-1,16            0.016796
# 11                 fBodyAcc-mad()-X            0.016776
# 12             fBodyAccJerk-std()-X            0.016439
# 13             angle(Y,gravityMean)            0.016210
# 14                tBodyAccMag-std()            0.015230
# 15                 tBodyAcc-max()-X            0.014165
# ...

# %%
df1.tail()
# Out:
#                      feature_name  feature_importance
# 556         fBodyGyro-entropy()-Z                 0.0
# 557             tBodyAccMag-min()                 0.0
# 558        tBodyAccMag-arCoeff()4                 0.0
# 559              fBodyAcc-min()-Y                 0.0
# 560  fBodyAcc-bandsEnergy()-49,64                 0.0

# %% [markdown]
# ### (2) 중요도 기반 feature 분석

# %% [markdown]
# * **세부 요구사항**
#     - 상위 n, 하위 m 개의 변수를 선정
#     - 선정된 변수(feature)와 target 간의 관계를 kdeplot으로 그리기

# %%
def draw_rel(target, feature, data):
    sns.kdeplot(data=data, x=feature, hue=target)
    plt.show()

# %% [markdown]
# #### 1) 상위 5, 하위 5개 변수 선정

# %%
top5 = list(df1.loc[:4,'feature_name'])
top5
# Out:
# ['tGravityAcc-min()-X',
#  'tGravityAcc-energy()-X',
#  'angle(X,gravityMean)',
#  'tGravityAcc-max()-X',
#  'tGravityAcc-mean()-X']

# %%
bot5 = list(df1.iloc[-5:]['feature_name'])
bot5
# Out:
# ['tBodyAccMag-min()',
#  'tBodyAccMag-iqr()',
#  'fBodyAccJerk-bandsEnergy()-1,8.1',
#  'fBodyAcc-bandsEnergy()-57,64',
#  'fBodyGyro-skewness()-Z']

# %% [markdown]
# #### 2) 상위 5개 변수에 대한 분석

# %%
for feature in top5:
  draw_rel(target, feature, data_train)

# %% [markdown]
# #### 3) 하위 5개 변수에 대한 분석

# %%
for feature in bot5:
  draw_rel(target, feature, data_train)

# %% [markdown]
# ## 4.미션2 : 데이터 분석2

# %% [markdown]
# 다음의 case에 맞게 feature 및 feature 그룹 중요도를 기반으로 탐색적 데이터 분석을 수행하시오.
# * Target을 **정적/동적 행동**으로 구분
#     * 6개의 행동은 2개의 그룹(정적행동, 동적행동)으로 나뉩니다.
#     * 어떤 feature(혹은 feature 그룹)이 2개 class 그룹(정적행동, 동적행동)를 구분하는데 중요한지를 찾아보고 탐색해봅시다.

# %% [markdown]
# ### (1) 정적/동적 행동으로 구분하여 분석하기

# %% [markdown]
# * **세부 요구사항**
#     - Target인 Activity를 is_dynamic 변수로 변경하시오.
#         * 값 0 : STANDING, SITTING, LAYING
#         * 값 1 : WALKING, WALKING_UPSTAIRS, WALKING_DOWNSTAIRS
#     - is_dynamic을 예측하기 위한 기본 모델을 생성하시오.
#         * x, is_dynamic을 이용하여 train과 validation으로 데이터 분할
#         * 기본 모델링
#     - is_dynamic 을 구분하는데 중요한 변수 상위 5를 분석하시오.
#     - is_dynamic 을 구분하는데 중요한 변수 그룹을 분석하시오.
#         * sensor별
#         * sensor+agg 별

# %% [markdown]
# #### 1) is_dynamic 추가

# %%
data_train['is_dynamic'] = data_train['Activity'].map({'STANDING':0, 'SITTING':0, 'LAYING':0,
                                                       'WALKING':1, 'WALKING_UPSTAIRS':1, 'WALKING_DOWNSTAIRS':1})

data_train.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288508          -0.009196          -0.103362         -0.988986
# 1           0.265757          -0.016576          -0.098163         -0.989551
# 2           0.278709          -0.014511          -0.108717         -0.997720
# 3           0.289795          -0.035536          -0.150354         -0.231727
# 4           0.394807           0.034098           0.091229          0.088489
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.962797         -0.967422         -0.989000         -0.962596
# 1         -0.994636         -0.987435         -0.990189         -0.993870
# 2         -0.981088         -0.994008         -0.997934         -0.982187
# 3         -0.006412         -0.338117         -0.273557          0.014245
# 4         -0.106636         -0.388502         -0.010469         -0.109680
#
# ...

# %% [markdown]
# #### 2) 기본모델 생성

# %%
target = 'is_dynamic'

x = data_train.drop(columns=[target, 'Activity'])
y = data_train[target]

# %%
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=0.2, random_state=1)

# %%
model_RF_dynamic = RandomForestClassifier(max_depth=5)

# %%
model_RF_dynamic.fit(x_train, y_train)
# Out:
# RandomForestClassifier(max_depth=5)

# %%
pred_dynamic = model_RF_dynamic.predict(x_val)

# %%
print(classification_report(y_val, pred_dynamic))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       655
#            1       1.00      1.00      1.00       522
#
#     accuracy                           1.00      1177
#    macro avg       1.00      1.00      1.00      1177
# weighted avg       1.00      1.00      1.00      1177

# %% [markdown]
# #### 3) 변수중요도 상위 5개 분석

# %%
df2 = plot_feature_importance(model_RF_dynamic.feature_importances_, x_train.columns, result_only=True)

# %%
df2.tail()
# Out:
#                         feature_name  importance_dynamic
# 45       fBodyAcc-bandsEnergy()-1,16            0.009897
# 46      fBodyBodyAccJerkMag-energy()            0.009897
# 47        fBodyBodyAccJerkMag-mean()            0.009889
# 48  fBodyAccJerk-bandsEnergy()-17,24            0.009881
# 49              tBodyAccJerk-iqr()-Z            0.009864

# %%
top5_dynamic = list(df2.loc[:5,'feature_name'])

# %%
for feature in top5_dynamic:
  draw_rel(target, feature, data_train)

# %% [markdown]
# ## 5.특성 중요도 저장하기

# %% [markdown]
# * **세부 요구사항**
#     - 지금까지 변수 중요도를 다양한 관점에서 뽑고 분석을 해 보았습니다.
#         - 관점1 : 6개 행동 구분
#         - 관점2 : 동적, 정적 행동 구분
#     - 모든 관점의 변수 중요도를 하나로 합친 후 저장
#         - merge를 이용하여 features와 합칩니다.
#         - joblib 패키지의 dump를 이용하여 결과를 저장합니다.

# %% [markdown]
# ### (1) 하나로 합치기
# * 합치기 위해서는 중요도 결과에서 feature_importance 칼럼 이름을 수정해야 합니다.
# * pd.merge를 이용해서 하나씩 합치는 작업을 반복 합니다.

# %% [markdown]
# #### 1) 이름변경

# %%
features.head()
# Out:
#      sensor     agg axis       feature_name
# 0  tBodyAcc  mean()    X  tBodyAcc-mean()-X
# 1  tBodyAcc  mean()    Y  tBodyAcc-mean()-Y
# 2  tBodyAcc  mean()    Z  tBodyAcc-mean()-Z
# 3  tBodyAcc   std()    X   tBodyAcc-std()-X
# 4  tBodyAcc   std()    Y   tBodyAcc-std()-Y

# %%
df1 = df1.rename(columns={'feature_importance':'importance'})
df2 = df2.rename(columns={'feature_importance':'importance_dynamic'})

# %%
df2.head()
# Out:
#                       feature_name  importance_dynamic
# 0  fBodyAccJerk-bandsEnergy()-1,24            0.049966
# 1             fBodyAccJerk-std()-X            0.040145
# 2         fBodyAccJerk-entropy()-X            0.040042
# 3             fBodyAccJerk-max()-X            0.040026
# 4          fBodyAccJerk-energy()-X            0.039991

# %% [markdown]
# #### 2) 합치기

# %%
merged_df1 = pd.merge(features, df1, how='left', on='feature_name')
merged_df1.head(3)
# Out:
#      sensor     agg axis       feature_name  importance
# 0  tBodyAcc  mean()    X  tBodyAcc-mean()-X    0.000085
# 1  tBodyAcc  mean()    Y  tBodyAcc-mean()-Y    0.000000
# 2  tBodyAcc  mean()    Z  tBodyAcc-mean()-Z    0.000000

# %%
merged_df2 = pd.merge(merged_df1, df2, how='left', on='feature_name')
merged_df2.head(20)
# Out:
#       sensor       agg axis         feature_name  importance  \
# 0   tBodyAcc    mean()    X    tBodyAcc-mean()-X    0.000085
# 1   tBodyAcc    mean()    Y    tBodyAcc-mean()-Y    0.000000
# 2   tBodyAcc    mean()    Z    tBodyAcc-mean()-Z    0.000000
# 3   tBodyAcc     std()    X     tBodyAcc-std()-X    0.009794
# 4   tBodyAcc     std()    Y     tBodyAcc-std()-Y    0.000229
# 5   tBodyAcc     std()    Z     tBodyAcc-std()-Z    0.000124
# 6   tBodyAcc     mad()    X     tBodyAcc-mad()-X    0.002053
# 7   tBodyAcc     mad()    Y     tBodyAcc-mad()-Y    0.000248
# 8   tBodyAcc     mad()    Z     tBodyAcc-mad()-Z    0.000129
# 9   tBodyAcc     max()    X     tBodyAcc-max()-X    0.012335
# 10  tBodyAcc     max()    Y     tBodyAcc-max()-Y    0.000007
# 11  tBodyAcc     max()    Z     tBodyAcc-max()-Z    0.000000
# 12  tBodyAcc     min()    X     tBodyAcc-min()-X    0.000056
# 13  tBodyAcc     min()    Y     tBodyAcc-min()-Y    0.002925
# ...

# %% [markdown]
# ### (2) 저장하기
# * joblib.dump를 이용하시오.
# * 저장할 파일의 확장자는 보통 .pkl 입니다.

# %%
joblib.dump(merged_df2, path + 'data_df.pkl')
# Out:
# ['/content/drive/MyDrive/mini_project3/data_df.pkl']
