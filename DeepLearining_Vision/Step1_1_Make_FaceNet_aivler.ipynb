# %% [markdown]
# # **Make Pretrained-Model FaceNet !**

# %% [markdown]
# ## 0.미션

# %% [markdown]
# ### (1) 미션1
# 여러분은 노트북에서 얼굴 인식 파일을 실행시키기 위해 사전 학습 모델을 만들어야 합니다.
#
# 그 전에 가지고 있는 데이터셋을 **학습에 적합한 형태**로 만들어야 합니다.
#
# - 1) 데이터셋을 불러옵니다.
#     - 데이터셋은 2가지입니다. 본인의 얼굴 이미지 파일, 다른 사람의 얼굴 이미지 파일.
# - 2) 데이터셋을 전처리합니다.
#     - Keras에는 **실제로 존재하는 이미지 데이터를 처리**해주는 함수가 있습니다.

# %% [markdown]
# ### (2) 미션2
# 데이터셋을 **학습에 적합한 형태**로 만들었다면, **FaceNet 모델로 Transfer Learning**을 수행합니다.
#
# - 1) FaceNet 모델 구조를 생성합니다.
#     - [FaceNet 논문 링크](https://arxiv.org/abs/1503.03832)
#     - FaceNet의 Input은 (160, 160) 사이즈의 이미지입니다.
# - 2) FaceNet 모델 구조 + 구조 추가
#     - FaceNet의 Output은 128차원의 벡터입니다.
#     - 이 과정을 Transfer Learning라고 합니다.

# %% [markdown]
# ### (3) 미션3
# 학습된 모델로 추론하여 성능 지표를 확인하고 모델을 개선시키세요.
#
# 그 후, 모델의 구조와 가중치를 **반드시 저장**하여 여러분의 노트북에 옮기세요.
#
# - 1) 다양한 모델을 사용해보세요.
#     - 모델에 정해진 정답은 없습니다.
#     - 성능 지표에서 무엇이 중요한지 깊게 생각하세요.
#     - 사전 학습된 FaceNet 모델을 사용하셔도 좋고, 아예 독창적으로 여러분만의 모델을 만드셔도 좋습니다!
# - 2) 모델을 **반드시 저장**하세요.
#     - .keras 형태로 우선 Colab에 저장하세요.
#     - Colab에 생성된 .keras 파일을 **로컬에 다운로드** 합니다.

# %% [markdown]
# ## 1.환경설정

# %% [markdown]
# * 세부 요구사항
#     - 경로 설정 : 구글콜랩
#         * 구글 드라이브 바로 밑에 project4 폴더를 만드세요.
#         * 데이터 파일을 복사해 넣습니다.
#         * 필요하다고 판단되는 라이브러리를 추가하세요.

# %% [markdown]
# ### (1) 경로 설정

# %% [markdown]
# * 구글 드라이브 연결

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = '/content/drive/MyDrive/project4'

# %% [markdown]
# ### (2) 라이브러리 설치 및 불러오기

# %% [markdown]
# * 라이브러리 로딩

# %%
## colab에서 세션 재시작을 요구하는 팝업이 뜨면 재시작 누르세요.
# !pip install keras-nightly
# Out:
# Requirement already satisfied: keras-nightly in /usr/local/lib/python3.10/dist-packages (3.7.0.dev2024102903)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras-nightly) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras-nightly) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras-nightly) (13.8.1)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras-nightly) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-nightly) (3.11.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras-nightly) (0.12.1)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from keras-nightly) (0.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras-nightly) (24.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from optree->keras-nightly) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras-nightly) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras-nightly) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras-nightly) (0.1.2)

# %% [markdown]
# ## 3.미션1

# %% [markdown]
# 여러분은 노트북에서 얼굴 인식 파일을 실행시키기 위해 사전 학습 모델을 만들어야 합니다.
#
# 그 전에 가지고 있는 데이터셋을 **학습에 적합한 형태**로 만들어야 합니다.
#
# - 1) 데이터셋을 불러옵니다.
#     - 데이터셋은 2가지입니다. 본인의 얼굴 이미지 파일, 다른 사람의 얼굴 이미지 파일.
# - 2) 데이터셋을 전처리합니다.
#     - Keras에는 **실제로 존재하는 이미지 데이터를 처리**해주는 함수가 있습니다.

# %% [markdown]
# ### (1) 데이터셋 불러오기

# %% [markdown]
# * **세부 요구사항**
#     - 데이터셋을 불러옵니다.
#         - 데이터셋은 두 개의 압축 파일이어야 합니다.
#             1. lfw-deepfunneled.zip : Labeled Faces in the Wild 데이터셋
#             2. 여러분의 얼굴 이미지 데이터셋
#                 - 여러분의 얼굴 이미지가 담긴 **압축 파일**을 **Google Drive에 업로드** 하기를 권장합니다.
#                     - 이미지 파일 하나하나 업로드 하면 시간이 오래 걸립니다.
#     - 데이터셋 압축 파일을 **Colab에 폴더를 생성한 후 해제**하세요.
#         - 데이터셋 폴더를 **본인 얼굴 폴더, LFW 폴더로 나누어** 생성하는 것을 권장합니다.
#         - 만일 두 압축 파일을 하나의 폴더에 모두 해제하면 전처리가 더 까다로워질 것입니다.
#     - 예시 코드에서 사용한 라이브러리
#         - os, zipfile

# %% [markdown]
# #### 1) 본인 얼굴 이미지 데이터셋 불러오기

# %%
import os, zipfile

# %%
data_me = path + '/Datasets/Keras/images_myface.zip'
data_others = path + '/Datasets/Keras/lfw-deepfunneled.zip'

# %%
def extract_zip(zip_file, extract_folder):
  if not os.path.exists(extract_folder):
      os.makedirs(extract_folder)

  with zipfile.ZipFile(zip_file, 'r') as zip_ref:
      file_list = zip_ref.namelist()
      for f in file_list:
          if not f.endswith('/') and f.lower().endswith('.jpg'):
              file_name = os.path.basename(f)

              if not file_name.startswith('._'):
                  d_path = os.path.join(extract_folder, file_name)

                  with zip_ref.open(f, 'r') as in_file, open(d_path, 'wb') as out_file:
                      out_file.write(in_file.read())

# %%
extract_zip(data_me, '/content/myface')

# %%
len(os.listdir('/content/myface'))
# Out:
# 3722

# %% [markdown]
# #### 2) 다른 얼굴 이미지 데이터셋 불러오기

# %%
extract_zip(data_others, '/content/others')

# %%
len(os.listdir('/content/others'))
# Out:
# 13233

# %% [markdown]
# ### (2) 데이터셋 전처리
# * **세부 요구사항**
#     - 데이터셋을 전처리 합니다.
#         - Training set, Validation set, Test set으로 데이터셋을 나누어 주세요.
#             - 학습 과정에서 Training set, Validation set을 사용해야 합니다.
#             - 추론 과정에서 Test set을 사용해야 합니다.
#         - Keras의 **특정 함수**가 실제 존재하는 이미지 파일에 대한 전처리를 쉽게 도와줍니다.
#         - **특정 함수**에서 요구하는 폴더 구조가 있습니다. **특정 함수**를 사용한다면 이에 맞춰서 폴더를 생성해야 합니다.
#         - 각 데이터셋에 스케일링도 적용하세요.
#     - 예시 코드에서 사용한 라이브러리
#         - glob, random, shutil, numpy, keras

# %% [markdown]
# #### 1) 데이터셋 분할

# %%
import glob, random, shutil
import numpy as np

from keras.utils import load_img, img_to_array, image_dataset_from_directory

# %%
# train, test 폴더 생성
data_train = '/content/train'
data_test = '/content/test'

if not os.path.exists(data_train):
    os.makedirs(data_train)
if not os.path.exists(data_test):
    os.makedirs(data_test)

# %%
# train, test 폴더에 클래스별 폴더 추가
class_names = ['me', 'others']

for folder in [data_train, data_test]:
  for class_name in class_names:
      class_path = os.path.join(folder, class_name)

      if not os.path.exists(class_path):
          os.makedirs(class_path)

# %%
images_me = sorted(glob.glob('/content/myface/*'))
images_others = sorted(glob.glob('/content/others/*'))

len(images_me)
# Out:
# 3722

# %%
random.seed(56)
random.shuffle(images_me)
random.shuffle(images_others)

images_me[:3]
# Out:
# ['/content/myface/myFace_2315.jpg',
#  '/content/myface/myFace_479.jpg',
#  '/content/myface/myFace_3319.jpg']

# %%
# 파일 split & copy move
def split_and_copy_files(src_folder, train_folder, test_folder, split_ratio=0.8):
    # 폴더 생성 (존재하지 않으면)
    os.makedirs(train_folder, exist_ok=True)
    os.makedirs(test_folder, exist_ok=True)

    # 원본 폴더에서 파일 목록 가져오기
    files = [f for f in os.listdir(src_folder) if os.path.isfile(os.path.join(src_folder, f))]

    # 파일 섞기
    random.shuffle(files)

    # 분할 비율에 맞게 파일 리스트 분리
    split_index = int(len(files) * split_ratio)
    train_files = files[:split_index]
    test_files = files[split_index:]

    # 파일 복사
    for file in train_files:
        shutil.copy(os.path.join(src_folder, file), os.path.join(train_folder, file))
    for file in test_files:
        shutil.copy(os.path.join(src_folder, file), os.path.join(test_folder, file))

    print(f"Train 폴더에 복사된 파일 개수: {len(train_files)}")
    print(f"Test 폴더에 복사된 파일 개수: {len(test_files)}")

# %%
src_folder = '/content/myface'
train_folder = '/content/train/me'
test_folder = '/content/test/me'

split_and_copy_files(src_folder, train_folder, test_folder)
# Out:
# Train 폴더에 복사된 파일 개수: 2977
# Test 폴더에 복사된 파일 개수: 745

# %%
src_folder = '/content/others'
train_folder = '/content/train/others'
test_folder = '/content/test/others'

split_and_copy_files(src_folder, train_folder, test_folder)
# Out:
# Train 폴더에 복사된 파일 개수: 10586
# Test 폴더에 복사된 파일 개수: 2647

# %% [markdown]
# #### 2) **특정 함수** 사용

# %%
# 데이터 폴더 > 데이터셋
train_id, val_id = image_dataset_from_directory(data_train,
                                                class_names = ['me' ,'others'],
                                                batch_size=32,
                                                image_size=(160, 160),
                                                shuffle=True,
                                                seed=56,
                                                validation_split=0.2,
                                                subset='both'
                                                )
# Out:
# Found 16250 files belonging to 2 classes.
# Using 13000 files for training.
# Using 3250 files for validation.

# %%
test_id = image_dataset_from_directory(data_test,
                                       class_names = ['me' ,'others'],
                                       batch_size=32,
                                       image_size=(160, 160),
                                       shuffle=True,
                                       seed=56,
                                       )
# Out:
# Found 6079 files belonging to 2 classes.

# %%
len(test_id)*32
# Out:
# 6080

# %% [markdown]
# #### 3) 스케일링

# %%
def rescale(image, label):
    image = image / 255.0
    return image, label

# %%
train_id_scaled = train_id.map(rescale)
val_id_scaled = val_id.map(rescale)
test_id_scaled = test_id.map(rescale)

# %% [markdown]
# ## 4.미션2

# %% [markdown]
# 데이터셋을 **학습에 적합한 형태**로 만들었다면, **FaceNet 모델로 Transfer Learning**을 수행합니다.
#
# - 1) FaceNet 모델 구조를 생성합니다.
#     - [FaceNet 논문 링크](https://arxiv.org/abs/1503.03832)
#     - FaceNet의 Input은 (160, 160) 사이즈의 이미지입니다.
# - 2) FaceNet 모델 구조 + 구조 추가
#     - FaceNet의 Output은 128차원의 벡터입니다.
#     - 이 과정을 Transfer Learning라고 합니다.

# %% [markdown]
# ### (1) FaceNet 구조 생성

# %% [markdown]
# * **세부 요구사항**
#     - FaceNet의 구조를 생성합니다.
#         - FaceNet 구조 생성에 필요한 함수를 만듭니다.
#     - FaceNet의 구조에 **잘 학습된 가중치**를 부여합니다.
#         - FaceNet 원본 가중치 파일을 공유하였습니다.
#     - (선택사항) FaceNet 모델의 가중치 업데이트를 방지합니다.
#     - 예시 코드에서 사용한 라이브러리
#         - numpy, functools, keras

# %% [markdown]
# #### 1) 모델 구조 생성

# %%
import numpy as np
from functools import partial


import keras
from keras.models import Model

from keras.layers import Input, Dense, Conv2D, MaxPooling2D, Activation
from keras.layers import BatchNormalization, Dropout, GlobalAveragePooling2D
from keras.layers import Lambda, Concatenate, add

from keras import backend as K
from keras.saving import register_keras_serializable

# %%
@register_keras_serializable()
def scaling(x, scale):
    return x * scale

@register_keras_serializable()
def conv2d_bn(x,
              filters,
              kernel_size,
              strides=1,
              padding='same',
              activation='relu',
              use_bias=False,
              name=None):
    x = Conv2D(filters,
               kernel_size,
               strides=strides,
               padding=padding,
               use_bias=use_bias,
               name=name)(x)
    if not use_bias:
        bn_axis = 1 if K.image_data_format() == 'channels_first' else 3
        bn_name = _generate_layer_name('BatchNorm', prefix=name)
        x = BatchNormalization(axis=bn_axis, momentum=0.995, epsilon=0.001,
                               scale=False, name=bn_name)(x)
    if activation is not None:
        ac_name = _generate_layer_name('Activation', prefix=name)
        x = Activation(activation, name=ac_name)(x)
    return x

@register_keras_serializable()
def _generate_layer_name(name, branch_idx=None, prefix=None):
    if prefix is None:
        return None
    if branch_idx is None:
        return '_'.join((prefix, name))
    return '_'.join((prefix, 'Branch', str(branch_idx), name))

@register_keras_serializable()
def _inception_resnet_block(x, scale, block_type, block_idx, activation='relu'):
    channel_axis = 1 if K.image_data_format() == 'channels_first' else 3
    if block_idx is None:
        prefix = None
    else:
        prefix = '_'.join((block_type, str(block_idx)))
    name_fmt = partial(_generate_layer_name, prefix=prefix)

    if block_type == 'Block35':
        branch_0 = conv2d_bn(x, 32, 1, name=name_fmt('Conv2d_1x1', 0))
        branch_1 = conv2d_bn(x, 32, 1, name=name_fmt('Conv2d_0a_1x1', 1))
        branch_1 = conv2d_bn(branch_1, 32, 3, name=name_fmt('Conv2d_0b_3x3', 1))
        branch_2 = conv2d_bn(x, 32, 1, name=name_fmt('Conv2d_0a_1x1', 2))
        branch_2 = conv2d_bn(branch_2, 32, 3, name=name_fmt('Conv2d_0b_3x3', 2))
        branch_2 = conv2d_bn(branch_2, 32, 3, name=name_fmt('Conv2d_0c_3x3', 2))
        branches = [branch_0, branch_1, branch_2]
    elif block_type == 'Block17':
        branch_0 = conv2d_bn(x, 128, 1, name=name_fmt('Conv2d_1x1', 0))
        branch_1 = conv2d_bn(x, 128, 1, name=name_fmt('Conv2d_0a_1x1', 1))
        branch_1 = conv2d_bn(branch_1, 128, [1, 7], name=name_fmt('Conv2d_0b_1x7', 1))
        branch_1 = conv2d_bn(branch_1, 128, [7, 1], name=name_fmt('Conv2d_0c_7x1', 1))
        branches = [branch_0, branch_1]
    elif block_type == 'Block8':
        branch_0 = conv2d_bn(x, 192, 1, name=name_fmt('Conv2d_1x1', 0))
        branch_1 = conv2d_bn(x, 192, 1, name=name_fmt('Conv2d_0a_1x1', 1))
        branch_1 = conv2d_bn(branch_1, 192, [1, 3], name=name_fmt('Conv2d_0b_1x3', 1))
        branch_1 = conv2d_bn(branch_1, 192, [3, 1], name=name_fmt('Conv2d_0c_3x1', 1))
        branches = [branch_0, branch_1]
    else:
        raise ValueError('Unknown Inception-ResNet block type. '
                         'Expects "Block35", "Block17" or "Block8", '
                         'but got: ' + str(block_type))

    mixed = Concatenate(axis=channel_axis, name=name_fmt('Concatenate'))(branches)
    up = conv2d_bn(mixed,
                #    K.int_shape(x)[channel_axis],
                   x.shape[channel_axis],
                   1,
                   activation=None,
                   use_bias=True,
                   name=name_fmt('Conv2d_1x1'))
    up = Lambda(scaling,
                # output_shape=K.int_shape(up)[1:],
                output_shape=up.shape[1:],
                arguments={'scale': scale})(up)
    x = add([x, up])
    if activation is not None:
        x = Activation(activation, name=name_fmt('Activation'))(x)
    return x

# %%
@register_keras_serializable()
def InceptionResNetV1(input_shape=(160, 160, 3),
                      classes=128,
                      dropout_keep_prob=0.8,
                      weights_path=None):
    inputs = Input(shape=input_shape)
    x = conv2d_bn(inputs, 32, 3, strides=2, padding='valid', name='Conv2d_1a_3x3')
    x = conv2d_bn(x, 32, 3, padding='valid', name='Conv2d_2a_3x3')
    x = conv2d_bn(x, 64, 3, name='Conv2d_2b_3x3')
    x = MaxPooling2D(3, strides=2, name='MaxPool_3a_3x3')(x)
    x = conv2d_bn(x, 80, 1, padding='valid', name='Conv2d_3b_1x1')
    x = conv2d_bn(x, 192, 3, padding='valid', name='Conv2d_4a_3x3')
    x = conv2d_bn(x, 256, 3, strides=2, padding='valid', name='Conv2d_4b_3x3')

    # 5x Block35 (Inception-ResNet-A block):
    for block_idx in range(1, 6):
        x = _inception_resnet_block(x,
                                    scale=0.17,
                                    block_type='Block35',
                                    block_idx=block_idx)

    # Mixed 6a (Reduction-A block):
    channel_axis = 1 if K.image_data_format() == 'channels_first' else 3
    name_fmt = partial(_generate_layer_name, prefix='Mixed_6a')
    branch_0 = conv2d_bn(x,
                         384,
                         3,
                         strides=2,
                         padding='valid',
                         name=name_fmt('Conv2d_1a_3x3', 0))
    branch_1 = conv2d_bn(x, 192, 1, name=name_fmt('Conv2d_0a_1x1', 1))
    branch_1 = conv2d_bn(branch_1, 192, 3, name=name_fmt('Conv2d_0b_3x3', 1))
    branch_1 = conv2d_bn(branch_1,
                         256,
                         3,
                         strides=2,
                         padding='valid',
                         name=name_fmt('Conv2d_1a_3x3', 1))
    branch_pool = MaxPooling2D(3,
                               strides=2,
                               padding='valid',
                               name=name_fmt('MaxPool_1a_3x3', 2))(x)
    branches = [branch_0, branch_1, branch_pool]
    x = Concatenate(axis=channel_axis, name='Mixed_6a')(branches)

    # 10x Block17 (Inception-ResNet-B block):
    for block_idx in range(1, 11):
        x = _inception_resnet_block(x,
                                    scale=0.1,
                                    block_type='Block17',
                                    block_idx=block_idx)

    # Mixed 7a (Reduction-B block): 8 x 8 x 2080
    name_fmt = partial(_generate_layer_name, prefix='Mixed_7a')
    branch_0 = conv2d_bn(x, 256, 1, name=name_fmt('Conv2d_0a_1x1', 0))
    branch_0 = conv2d_bn(branch_0,
                         384,
                         3,
                         strides=2,
                         padding='valid',
                         name=name_fmt('Conv2d_1a_3x3', 0))
    branch_1 = conv2d_bn(x, 256, 1, name=name_fmt('Conv2d_0a_1x1', 1))
    branch_1 = conv2d_bn(branch_1,
                         256,
                         3,
                         strides=2,
                         padding='valid',
                         name=name_fmt('Conv2d_1a_3x3', 1))
    branch_2 = conv2d_bn(x, 256, 1, name=name_fmt('Conv2d_0a_1x1', 2))
    branch_2 = conv2d_bn(branch_2, 256, 3, name=name_fmt('Conv2d_0b_3x3', 2))
    branch_2 = conv2d_bn(branch_2,
                         256,
                         3,
                         strides=2,
                         padding='valid',
                         name=name_fmt('Conv2d_1a_3x3', 2))
    branch_pool = MaxPooling2D(3,
                               strides=2,
                               padding='valid',
                               name=name_fmt('MaxPool_1a_3x3', 3))(x)
    branches = [branch_0, branch_1, branch_2, branch_pool]
    x = Concatenate(axis=channel_axis, name='Mixed_7a')(branches)

    # 5x Block8 (Inception-ResNet-C block):
    for block_idx in range(1, 6):
        x = _inception_resnet_block(x,
                                    scale=0.2,
                                    block_type='Block8',
                                    block_idx=block_idx)
    x = _inception_resnet_block(x,
                                scale=1.,
                                activation=None,
                                block_type='Block8',
                                block_idx=6)

    # Classification block
    x = GlobalAveragePooling2D(name='AvgPool')(x)
    x = Dropout(1.0 - dropout_keep_prob, name='Dropout')(x)
    # Bottleneck
    x = Dense(classes, use_bias=False, name='Bottleneck')(x)
    bn_name = _generate_layer_name('BatchNorm', prefix='Bottleneck')
    x = BatchNormalization(momentum=0.995, epsilon=0.001, scale=False,
                           name=bn_name)(x)

    # Create model
    model = Model(inputs, x, name='inception_resnet_v1')
    if weights_path is not None:
        model.load_weights(weights_path)

    return model

# %%
facenet_model = InceptionResNetV1()

# %%
len(facenet_model.layers)
# Out:
# 447

# %%
facenet_model.summary()
# Out:
# Model: "inception_resnet_v1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1             │ (None, 160, 160, 3)    │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_1a_3x3 (Conv2D)    │ (None, 79, 79, 32)     │            864 │ input_layer_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_1a_3x3_BatchNorm   │ (None, 79, 79, 32)     │             96 │ Conv2d_1a_3x3[0][0]    │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_1a_3x3_Activation  │ (None, 79, 79, 32)     │              0 │ Conv2d_1a_3x3_BatchNo… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_2a_3x3 (Conv2D)    │ (None, 77, 77, 32)     │          9,216 │ Conv2d_1a_3x3_Activat… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_2a_3x3_BatchNorm   │ (None, 77, 77, 32)     │             96 │ Conv2d_2a_3x3[0][0]    │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_2a_3x3_Activation  │ (None, 77, 77, 32)     │              0 │ Conv2d_2a_3x3_BatchNo… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_2b_3x3 (Conv2D)    │ (None, 77, 77, 64)     │         18,432 │ Conv2d_2a_3x3_Activat… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_2b_3x3_BatchNorm   │ (None, 77, 77, 64)     │            192 │ Conv2d_2b_3x3[0][0]    │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_2b_3x3_Activation  │ (None, 77, 77, 64)     │              0 │ Conv2d_2b_3x3_BatchNo… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ MaxPool_3a_3x3            │ (None, 38, 38, 64)     │              0 │ Conv2d_2b_3x3_Activat… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_3b_1x1 (Conv2D)    │ (None, 38, 38, 80)     │          5,120 │ MaxPool_3a_3x3[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_3b_1x1_BatchNorm   │ (None, 38, 38, 80)     │            240 │ Conv2d_3b_1x1[0][0]    │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_3b_1x1_Activation  │ (None, 38, 38, 80)     │              0 │ Conv2d_3b_1x1_BatchNo… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_4a_3x3 (Conv2D)    │ (None, 36, 36, 192)    │        138,240 │ Conv2d_3b_1x1_Activat… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_4a_3x3_BatchNorm   │ (None, 36, 36, 192)    │            576 │ Conv2d_4a_3x3[0][0]    │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_4a_3x3_Activation  │ (None, 36, 36, 192)    │              0 │ Conv2d_4a_3x3_BatchNo… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_4b_3x3 (Conv2D)    │ (None, 17, 17, 256)    │        442,368 │ Conv2d_4a_3x3_Activat… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_4b_3x3_BatchNorm   │ (None, 17, 17, 256)    │            768 │ Conv2d_4b_3x3[0][0]    │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_4b_3x3_Activation  │ (None, 17, 17, 256)    │              0 │ Conv2d_4b_3x3_BatchNo… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_2_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Conv2d_4b_3x3_Activat… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_1_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_1_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_1_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Conv2d_4b_3x3_Activat… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_2_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_1_Branch_2_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_1_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_1_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_1_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_1_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_1_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_1_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_0_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Conv2d_4b_3x3_Activat… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_1_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_1_Branch_1_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_2_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_1_Branch_2_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_0_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_1_Branch_0_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_1_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_1_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_1_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_0_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_1_Branch_0_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_1_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_1_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_1_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Concatenate     │ (None, 17, 17, 96)     │              0 │ Block35_1_Branch_0_Co… │
# │ (Concatenate)             │                        │                │ Block35_1_Branch_1_Co… │
# │                           │                        │                │ Block35_1_Branch_2_Co… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Conv2d_1x1      │ (None, 17, 17, 256)    │         24,832 │ Block35_1_Concatenate… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda (Lambda)           │ (None, 17, 17, 256)    │              0 │ Block35_1_Conv2d_1x1[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add (Add)                 │ (None, 17, 17, 256)    │              0 │ Conv2d_4b_3x3_Activat… │
# │                           │                        │                │ lambda[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Activation      │ (None, 17, 17, 256)    │              0 │ add[0][0]              │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_2_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_1_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_2_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_2_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_1_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_1_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_2_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_2_Branch_2_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_1_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_2_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_2_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_1_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_2_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_2_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_0_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_1_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_1_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_2_Branch_1_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_2_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_2_Branch_2_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_0_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_2_Branch_0_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_1_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_2_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_2_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_0_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_2_Branch_0_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_1_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_2_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_2_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Concatenate     │ (None, 17, 17, 96)     │              0 │ Block35_2_Branch_0_Co… │
# │ (Concatenate)             │                        │                │ Block35_2_Branch_1_Co… │
# │                           │                        │                │ Block35_2_Branch_2_Co… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Conv2d_1x1      │ (None, 17, 17, 256)    │         24,832 │ Block35_2_Concatenate… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_1 (Lambda)         │ (None, 17, 17, 256)    │              0 │ Block35_2_Conv2d_1x1[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_1 (Add)               │ (None, 17, 17, 256)    │              0 │ Block35_1_Activation[… │
# │                           │                        │                │ lambda_1[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Activation      │ (None, 17, 17, 256)    │              0 │ add_1[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_2_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_2_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_3_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_3_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_1_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_2_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_2_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_3_Branch_2_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_1_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_3_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_3_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_1_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_3_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_3_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_0_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_2_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_1_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_3_Branch_1_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_2_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_3_Branch_2_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_0_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_3_Branch_0_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_1_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_3_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_3_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_0_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_3_Branch_0_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_1_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_3_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_3_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Concatenate     │ (None, 17, 17, 96)     │              0 │ Block35_3_Branch_0_Co… │
# │ (Concatenate)             │                        │                │ Block35_3_Branch_1_Co… │
# │                           │                        │                │ Block35_3_Branch_2_Co… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Conv2d_1x1      │ (None, 17, 17, 256)    │         24,832 │ Block35_3_Concatenate… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_2 (Lambda)         │ (None, 17, 17, 256)    │              0 │ Block35_3_Conv2d_1x1[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_2 (Add)               │ (None, 17, 17, 256)    │              0 │ Block35_2_Activation[… │
# │                           │                        │                │ lambda_2[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Activation      │ (None, 17, 17, 256)    │              0 │ add_2[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_2_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_3_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_4_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_4_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_1_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_3_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_2_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_4_Branch_2_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_1_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_4_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_4_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_1_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_4_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_4_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_0_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_3_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_1_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_4_Branch_1_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_2_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_4_Branch_2_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_0_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_4_Branch_0_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_1_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_4_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_4_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_0_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_4_Branch_0_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_1_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_4_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_4_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Concatenate     │ (None, 17, 17, 96)     │              0 │ Block35_4_Branch_0_Co… │
# │ (Concatenate)             │                        │                │ Block35_4_Branch_1_Co… │
# │                           │                        │                │ Block35_4_Branch_2_Co… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Conv2d_1x1      │ (None, 17, 17, 256)    │         24,832 │ Block35_4_Concatenate… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_3 (Lambda)         │ (None, 17, 17, 256)    │              0 │ Block35_4_Conv2d_1x1[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_3 (Add)               │ (None, 17, 17, 256)    │              0 │ Block35_3_Activation[… │
# │                           │                        │                │ lambda_3[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Activation      │ (None, 17, 17, 256)    │              0 │ add_3[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_2_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_4_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_5_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_5_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_1_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_4_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_2_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_5_Branch_2_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_1_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_5_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_5_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_1_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_5_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_5_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_0_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_4_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_1_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_5_Branch_1_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_2_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_5_Branch_2_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_0_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_5_Branch_0_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_1_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_5_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_5_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_0_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_5_Branch_0_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_1_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_5_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_5_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Concatenate     │ (None, 17, 17, 96)     │              0 │ Block35_5_Branch_0_Co… │
# │ (Concatenate)             │                        │                │ Block35_5_Branch_1_Co… │
# │                           │                        │                │ Block35_5_Branch_2_Co… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Conv2d_1x1      │ (None, 17, 17, 256)    │         24,832 │ Block35_5_Concatenate… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_4 (Lambda)         │ (None, 17, 17, 256)    │              0 │ Block35_5_Conv2d_1x1[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_4 (Add)               │ (None, 17, 17, 256)    │              0 │ Block35_4_Activation[… │
# │                           │                        │                │ lambda_4[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Activation      │ (None, 17, 17, 256)    │              0 │ add_4[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_1_Conv2d… │ (None, 17, 17, 192)    │         49,152 │ Block35_5_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_1_Conv2d… │ (None, 17, 17, 192)    │            576 │ Mixed_6a_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_1_Conv2d… │ (None, 17, 17, 192)    │              0 │ Mixed_6a_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_1_Conv2d… │ (None, 17, 17, 192)    │        331,776 │ Mixed_6a_Branch_1_Con… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_1_Conv2d… │ (None, 17, 17, 192)    │            576 │ Mixed_6a_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_1_Conv2d… │ (None, 17, 17, 192)    │              0 │ Mixed_6a_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_0_Conv2d… │ (None, 8, 8, 384)      │        884,736 │ Block35_5_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_1_Conv2d… │ (None, 8, 8, 256)      │        442,368 │ Mixed_6a_Branch_1_Con… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_0_Conv2d… │ (None, 8, 8, 384)      │          1,152 │ Mixed_6a_Branch_0_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_1_Conv2d… │ (None, 8, 8, 256)      │            768 │ Mixed_6a_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_0_Conv2d… │ (None, 8, 8, 384)      │              0 │ Mixed_6a_Branch_0_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_1_Conv2d… │ (None, 8, 8, 256)      │              0 │ Mixed_6a_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_2_MaxPoo… │ (None, 8, 8, 256)      │              0 │ Block35_5_Activation[… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a (Concatenate)    │ (None, 8, 8, 896)      │              0 │ Mixed_6a_Branch_0_Con… │
# │                           │                        │                │ Mixed_6a_Branch_1_Con… │
# │                           │                        │                │ Mixed_6a_Branch_2_Max… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_1_Conv2… │ (None, 8, 8, 128)      │        114,688 │ Mixed_6a[0][0]         │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_1_Conv2… │ (None, 8, 8, 128)      │            384 │ Block17_1_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_1_Conv2… │ (None, 8, 8, 128)      │              0 │ Block17_1_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_1_Conv2… │ (None, 8, 8, 128)      │        114,688 │ Block17_1_Branch_1_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_1_Conv2… │ (None, 8, 8, 128)      │            384 │ Block17_1_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_1_Conv2… │ (None, 8, 8, 128)      │              0 │ Block17_1_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_0_Conv2… │ (None, 8, 8, 128)      │        114,688 │ Mixed_6a[0][0]         │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_1_Conv2… │ (None, 8, 8, 128)      │        114,688 │ Block17_1_Branch_1_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_0_Conv2… │ (None, 8, 8, 128)      │            384 │ Block17_1_Branch_0_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_1_Conv2… │ (None, 8, 8, 128)      │            384 │ Block17_1_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_0_Conv2… │ (None, 8, 8, 128)      │              0 │ Block17_1_Branch_0_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_1_Conv2… │ (None, 8, 8, 128)      │              0 │ Block17_1_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Concatenate     │ (None, 8, 8, 256)      │              0 │ Block17_1_Branch_0_Co… │
# │ (Concatenate)             │                        │                │ Block17_1_Branch_1_Co… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Conv2d_1x1      │ (None, 8, 8, 896)      │        230,272 │ Block17_1_Concatenate… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_5 (Lambda)         │ (None, 8, 8, 896)      │              0 │ Block17_1_Conv2d_1x1[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_5 (Add)               │ (None, 8, 8, 896)      │              0 │ Mixed_6a[0][0],        │
# │                           │                        │                │ lambda_5[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Activation      │ (None, 8, 8, 896)      │              0 │ add_5[0][0]            │
# │ (Activation)              │                        │                │                        │
# ...
# │ add_17 (Add)              │ (None, 3, 3, 1792)     │              0 │ Block8_2_Activation[0… │
# │                           │                        │                │ lambda_17[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_3_Activation       │ (None, 3, 3, 1792)     │              0 │ add_17[0][0]           │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_1_Conv2d… │ (None, 3, 3, 192)      │        344,064 │ Block8_3_Activation[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_1_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_4_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_1_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_4_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_1_Conv2d… │ (None, 3, 3, 192)      │        110,592 │ Block8_4_Branch_1_Con… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_1_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_4_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_1_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_4_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_0_Conv2d… │ (None, 3, 3, 192)      │        344,064 │ Block8_3_Activation[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_1_Conv2d… │ (None, 3, 3, 192)      │        110,592 │ Block8_4_Branch_1_Con… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_0_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_4_Branch_0_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_1_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_4_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_0_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_4_Branch_0_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_1_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_4_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Concatenate      │ (None, 3, 3, 384)      │              0 │ Block8_4_Branch_0_Con… │
# │ (Concatenate)             │                        │                │ Block8_4_Branch_1_Con… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Conv2d_1x1       │ (None, 3, 3, 1792)     │        689,920 │ Block8_4_Concatenate[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_18 (Lambda)        │ (None, 3, 3, 1792)     │              0 │ Block8_4_Conv2d_1x1[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_18 (Add)              │ (None, 3, 3, 1792)     │              0 │ Block8_3_Activation[0… │
# │                           │                        │                │ lambda_18[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Activation       │ (None, 3, 3, 1792)     │              0 │ add_18[0][0]           │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_1_Conv2d… │ (None, 3, 3, 192)      │        344,064 │ Block8_4_Activation[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_1_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_5_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_1_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_5_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_1_Conv2d… │ (None, 3, 3, 192)      │        110,592 │ Block8_5_Branch_1_Con… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_1_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_5_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_1_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_5_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_0_Conv2d… │ (None, 3, 3, 192)      │        344,064 │ Block8_4_Activation[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_1_Conv2d… │ (None, 3, 3, 192)      │        110,592 │ Block8_5_Branch_1_Con… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_0_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_5_Branch_0_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_1_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_5_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_0_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_5_Branch_0_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_1_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_5_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Concatenate      │ (None, 3, 3, 384)      │              0 │ Block8_5_Branch_0_Con… │
# │ (Concatenate)             │                        │                │ Block8_5_Branch_1_Con… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Conv2d_1x1       │ (None, 3, 3, 1792)     │        689,920 │ Block8_5_Concatenate[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_19 (Lambda)        │ (None, 3, 3, 1792)     │              0 │ Block8_5_Conv2d_1x1[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_19 (Add)              │ (None, 3, 3, 1792)     │              0 │ Block8_4_Activation[0… │
# │                           │                        │                │ lambda_19[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Activation       │ (None, 3, 3, 1792)     │              0 │ add_19[0][0]           │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_1_Conv2d… │ (None, 3, 3, 192)      │        344,064 │ Block8_5_Activation[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_1_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_6_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_1_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_6_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_1_Conv2d… │ (None, 3, 3, 192)      │        110,592 │ Block8_6_Branch_1_Con… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_1_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_6_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_1_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_6_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_0_Conv2d… │ (None, 3, 3, 192)      │        344,064 │ Block8_5_Activation[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_1_Conv2d… │ (None, 3, 3, 192)      │        110,592 │ Block8_6_Branch_1_Con… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_0_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_6_Branch_0_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_1_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_6_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_0_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_6_Branch_0_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_1_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_6_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Concatenate      │ (None, 3, 3, 384)      │              0 │ Block8_6_Branch_0_Con… │
# │ (Concatenate)             │                        │                │ Block8_6_Branch_1_Con… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Conv2d_1x1       │ (None, 3, 3, 1792)     │        689,920 │ Block8_6_Concatenate[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_20 (Lambda)        │ (None, 3, 3, 1792)     │              0 │ Block8_6_Conv2d_1x1[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_20 (Add)              │ (None, 3, 3, 1792)     │              0 │ Block8_5_Activation[0… │
# │                           │                        │                │ lambda_20[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ AvgPool                   │ (None, 1792)           │              0 │ add_20[0][0]           │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Dropout (Dropout)         │ (None, 1792)           │              0 │ AvgPool[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Bottleneck (Dense)        │ (None, 128)            │        229,376 │ Dropout[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Bottleneck_BatchNorm      │ (None, 128)            │            384 │ Bottleneck[0][0]       │
# │ (BatchNormalization)      │                        │                │                        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 22,808,144 (87.01 MB)
#  Trainable params: 22,779,312 (86.90 MB)
#  Non-trainable params: 28,832 (112.62 KB)

# %% [markdown]
# #### 2) 모델에 가중치 적용

# %%
## FaceNet 가중치 파일 경로 설정
weights_path = path + '/Datasets/Keras/facenet_model_weights.npz'
weights_path
# Out:
# '/content/drive/MyDrive/project4/Datasets/Keras/facenet_model_weights.npz'

# %%
## 가중치 파일 불러오기
loaded_weights = np.load(weights_path)

loaded_weights
# Out:
# NpzFile '/content/drive/MyDrive/project4/Datasets/Keras/facenet_model_weights.npz' with keys: arr_0, arr_1, arr_2, arr_3, arr_4...

# %%
## FaceNet 각 레이어에 가중치 적용
facenet_model.set_weights([loaded_weights[key] for key in loaded_weights])

# %% [markdown]
# #### 3) 모델의 가중치 업데이트 방지 (선택사항)

# %%
## FaceNet 전체 레이어 확인
facenet_model.layers
# Out:
# [<InputLayer name=input_layer_1, built=True>,
#  <Conv2D name=Conv2d_1a_3x3, built=True>,
#  <BatchNormalization name=Conv2d_1a_3x3_BatchNorm, built=True>,
#  <Activation name=Conv2d_1a_3x3_Activation, built=True>,
#  <Conv2D name=Conv2d_2a_3x3, built=True>,
#  <BatchNormalization name=Conv2d_2a_3x3_BatchNorm, built=True>,
#  <Activation name=Conv2d_2a_3x3_Activation, built=True>,
#  <Conv2D name=Conv2d_2b_3x3, built=True>,
#  <BatchNormalization name=Conv2d_2b_3x3_BatchNorm, built=True>,
#  <Activation name=Conv2d_2b_3x3_Activation, built=True>,
#  <MaxPooling2D name=MaxPool_3a_3x3, built=True>,
#  <Conv2D name=Conv2d_3b_1x1, built=True>,
#  <BatchNormalization name=Conv2d_3b_1x1_BatchNorm, built=True>,
#  <Activation name=Conv2d_3b_1x1_Activation, built=True>,
#  <Conv2D name=Conv2d_4a_3x3, built=True>,
#  <BatchNormalization name=Conv2d_4a_3x3_BatchNorm, built=True>,
#  <Activation name=Conv2d_4a_3x3_Activation, built=True>,
#  <Conv2D name=Conv2d_4b_3x3, built=True>,
#  <BatchNormalization name=Conv2d_4b_3x3_BatchNorm, built=True>,
#  <Activation name=Conv2d_4b_3x3_Activation, built=True>,
#  <Conv2D name=Block35_1_Branch_2_Conv2d_0a_1x1, built=True>,
#  <BatchNormalization name=Block35_1_Branch_2_Conv2d_0a_1x1_BatchNorm, built=True>,
#  <Activation name=Block35_1_Branch_2_Conv2d_0a_1x1_Activation, built=True>,
#  <Conv2D name=Block35_1_Branch_1_Conv2d_0a_1x1, built=True>,
#  <Conv2D name=Block35_1_Branch_2_Conv2d_0b_3x3, built=True>,
#  <BatchNormalization name=Block35_1_Branch_1_Conv2d_0a_1x1_BatchNorm, built=True>,
#  <BatchNormalization name=Block35_1_Branch_2_Conv2d_0b_3x3_BatchNorm, built=True>,
#  <Activation name=Block35_1_Branch_1_Conv2d_0a_1x1_Activation, built=True>,
#  <Activation name=Block35_1_Branch_2_Conv2d_0b_3x3_Activation, built=True>,
#  <Conv2D name=Block35_1_Branch_0_Conv2d_1x1, built=True>,
#  <Conv2D name=Block35_1_Branch_1_Conv2d_0b_3x3, built=True>,
#  <Conv2D name=Block35_1_Branch_2_Conv2d_0c_3x3, built=True>,
#  <BatchNormalization name=Block35_1_Branch_0_Conv2d_1x1_BatchNorm, built=True>,
#  <BatchNormalization name=Block35_1_Branch_1_Conv2d_0b_3x3_BatchNorm, built=True>,
#  <BatchNormalization name=Block35_1_Branch_2_Conv2d_0c_3x3_BatchNorm, built=True>,
#  <Activation name=Block35_1_Branch_0_Conv2d_1x1_Activation, built=True>,
#  <Activation name=Block35_1_Branch_1_Conv2d_0b_3x3_Activation, built=True>,
#  <Activation name=Block35_1_Branch_2_Conv2d_0c_3x3_Activation, built=True>,
#  <Concatenate name=Block35_1_Concatenate, built=True>,
#  <Conv2D name=Block35_1_Conv2d_1x1, built=True>,
#  <Lambda name=lambda, built=True>,
#  <Add name=add, built=True>,
#  <Activation name=Block35_1_Activation, built=True>,
#  <Conv2D name=Block35_2_Branch_2_Conv2d_0a_1x1, built=True>,
#  <BatchNormalization name=Block35_2_Branch_2_Conv2d_0a_1x1_BatchNorm, built=True>,
#  <Activation name=Block35_2_Branch_2_Conv2d_0a_1x1_Activation, built=True>,
#  <Conv2D name=Block35_2_Branch_1_Conv2d_0a_1x1, built=True>,
#  <Conv2D name=Block35_2_Branch_2_Conv2d_0b_3x3, built=True>,
#  <BatchNormalization name=Block35_2_Branch_1_Conv2d_0a_1x1_BatchNorm, built=True>,
#  <BatchNormalization name=Block35_2_Branch_2_Conv2d_0b_3x3_BatchNorm, built=True>,
#  <Activation name=Block35_2_Branch_1_Conv2d_0a_1x1_Activation, built=True>,
#  <Activation name=Block35_2_Branch_2_Conv2d_0b_3x3_Activation, built=True>,
#  <Conv2D name=Block35_2_Branch_0_Conv2d_1x1, built=True>,
#  <Conv2D name=Block35_2_Branch_1_Conv2d_0b_3x3, built=True>,
#  <Conv2D name=Block35_2_Branch_2_Conv2d_0c_3x3, built=True>,
#  <BatchNormalization name=Block35_2_Branch_0_Conv2d_1x1_BatchNorm, built=True>,
#  <BatchNormalization name=Block35_2_Branch_1_Conv2d_0b_3x3_BatchNorm, built=True>,
#  <BatchNormalization name=Block35_2_Branch_2_Conv2d_0c_3x3_BatchNorm, built=True>,
#  <Activation name=Block35_2_Branch_0_Conv2d_1x1_Activation, built=True>,
#  <Activation name=Block35_2_Branch_1_Conv2d_0b_3x3_Activation, built=True>,
#  <Activation name=Block35_2_Branch_2_Conv2d_0c_3x3_Activation, built=True>,
#  <Concatenate name=Block35_2_Concatenate, built=True>,
#  <Conv2D name=Block35_2_Conv2d_1x1, built=True>,
#  <Lambda name=lambda_1, built=True>,
#  <Add name=add_1, built=True>,
#  <Activation name=Block35_2_Activation, built=True>,
#  <Conv2D name=Block35_3_Branch_2_Conv2d_0a_1x1, built=True>,
#  <BatchNormalization name=Block35_3_Branch_2_Conv2d_0a_1x1_BatchNorm, built=True>,
#  <Activation name=Block35_3_Branch_2_Conv2d_0a_1x1_Activation, built=True>,
#  <Conv2D name=Block35_3_Branch_1_Conv2d_0a_1x1, built=True>,
#  <Conv2D name=Block35_3_Branch_2_Conv2d_0b_3x3, built=True>,
#  <BatchNormalization name=Block35_3_Branch_1_Conv2d_0a_1x1_BatchNorm, built=True>,
#  <BatchNormalization name=Block35_3_Branch_2_Conv2d_0b_3x3_BatchNorm, built=True>,
#  <Activation name=Block35_3_Branch_1_Conv2d_0a_1x1_Activation, built=True>,
#  <Activation name=Block35_3_Branch_2_Conv2d_0b_3x3_Activation, built=True>,
#  <Conv2D name=Block35_3_Branch_0_Conv2d_1x1, built=True>,
#  <Conv2D name=Block35_3_Branch_1_Conv2d_0b_3x3, built=True>,
#  <Conv2D name=Block35_3_Branch_2_Conv2d_0c_3x3, built=True>,
#  <BatchNormalization name=Block35_3_Branch_0_Conv2d_1x1_BatchNorm, built=True>,
#  <BatchNormalization name=Block35_3_Branch_1_Conv2d_0b_3x3_BatchNorm, built=True>,
#  <BatchNormalization name=Block35_3_Branch_2_Conv2d_0c_3x3_BatchNorm, built=True>,
#  <Activation name=Block35_3_Branch_0_Conv2d_1x1_Activation, built=True>,
#  <Activation name=Block35_3_Branch_1_Conv2d_0b_3x3_Activation, built=True>,
#  <Activation name=Block35_3_Branch_2_Conv2d_0c_3x3_Activation, built=True>,
#  <Concatenate name=Block35_3_Concatenate, built=True>,
#  <Conv2D name=Block35_3_Conv2d_1x1, built=True>,
#  <Lambda name=lambda_2, built=True>,
#  <Add name=add_2, built=True>,
#  <Activation name=Block35_3_Activation, built=True>,
#  <Conv2D name=Block35_4_Branch_2_Conv2d_0a_1x1, built=True>,
#  <BatchNormalization name=Block35_4_Branch_2_Conv2d_0a_1x1_BatchNorm, built=True>,
#  <Activation name=Block35_4_Branch_2_Conv2d_0a_1x1_Activation, built=True>,
#  <Conv2D name=Block35_4_Branch_1_Conv2d_0a_1x1, built=True>,
#  <Conv2D name=Block35_4_Branch_2_Conv2d_0b_3x3, built=True>,
#  <BatchNormalization name=Block35_4_Branch_1_Conv2d_0a_1x1_BatchNorm, built=True>,
#  <BatchNormalization name=Block35_4_Branch_2_Conv2d_0b_3x3_BatchNorm, built=True>,
#  <Activation name=Block35_4_Branch_1_Conv2d_0a_1x1_Activation, built=True>,
#  <Activation name=Block35_4_Branch_2_Conv2d_0b_3x3_Activation, built=True>,
#  <Conv2D name=Block35_4_Branch_0_Conv2d_1x1, built=True>,
#  <Conv2D name=Block35_4_Branch_1_Conv2d_0b_3x3, built=True>,
#  <Conv2D name=Block35_4_Branch_2_Conv2d_0c_3x3, built=True>,
#  <BatchNormalization name=Block35_4_Branch_0_Conv2d_1x1_BatchNorm, built=True>,
#  <BatchNormalization name=Block35_4_Branch_1_Conv2d_0b_3x3_BatchNorm, built=True>,
#  <BatchNormalization name=Block35_4_Branch_2_Conv2d_0c_3x3_BatchNorm, built=True>,
#  <Activation name=Block35_4_Branch_0_Conv2d_1x1_Activation, built=True>,
#  <Activation name=Block35_4_Branch_1_Conv2d_0b_3x3_Activation, built=True>,
#  <Activation name=Block35_4_Branch_2_Conv2d_0c_3x3_Activation, built=True>,
#  <Concatenate name=Block35_4_Concatenate, built=True>,
#  <Conv2D name=Block35_4_Conv2d_1x1, built=True>,
#  <Lambda name=lambda_3, built=True>,
#  <Add name=add_3, built=True>,
#  <Activation name=Block35_4_Activation, built=True>,
#  <Conv2D name=Block35_5_Branch_2_Conv2d_0a_1x1, built=True>,
#  <BatchNormalization name=Block35_5_Branch_2_Conv2d_0a_1x1_BatchNorm, built=True>,
#  <Activation name=Block35_5_Branch_2_Conv2d_0a_1x1_Activation, built=True>,
#  <Conv2D name=Block35_5_Branch_1_Conv2d_0a_1x1, built=True>,
#  <Conv2D name=Block35_5_Branch_2_Conv2d_0b_3x3, built=True>,
#  <BatchNormalization name=Block35_5_Branch_1_Conv2d_0a_1x1_BatchNorm, built=True>,
#  <BatchNormalization name=Block35_5_Branch_2_Conv2d_0b_3x3_BatchNorm, built=True>,
#  <Activation name=Block35_5_Branch_1_Conv2d_0a_1x1_Activation, built=True>,
#  <Activation name=Block35_5_Branch_2_Conv2d_0b_3x3_Activation, built=True>,
#  <Conv2D name=Block35_5_Branch_0_Conv2d_1x1, built=True>,
#  <Conv2D name=Block35_5_Branch_1_Conv2d_0b_3x3, built=True>,
#  <Conv2D name=Block35_5_Branch_2_Conv2d_0c_3x3, built=True>,
#  <BatchNormalization name=Block35_5_Branch_0_Conv2d_1x1_BatchNorm, built=True>,
#  <BatchNormalization name=Block35_5_Branch_1_Conv2d_0b_3x3_BatchNorm, built=True>,
#  <BatchNormalization name=Block35_5_Branch_2_Conv2d_0c_3x3_BatchNorm, built=True>,
#  <Activation name=Block35_5_Branch_0_Conv2d_1x1_Activation, built=True>,
#  <Activation name=Block35_5_Branch_1_Conv2d_0b_3x3_Activation, built=True>,
#  <Activation name=Block35_5_Branch_2_Conv2d_0c_3x3_Activation, built=True>,
#  <Concatenate name=Block35_5_Concatenate, built=True>,
#  <Conv2D name=Block35_5_Conv2d_1x1, built=True>,
#  <Lambda name=lambda_4, built=True>,
#  <Add name=add_4, built=True>,
#  <Activation name=Block35_5_Activation, built=True>,
#  <Conv2D name=Mixed_6a_Branch_1_Conv2d_0a_1x1, built=True>,
#  <BatchNormalization name=Mixed_6a_Branch_1_Conv2d_0a_1x1_BatchNorm, built=True>,
#  <Activation name=Mixed_6a_Branch_1_Conv2d_0a_1x1_Activation, built=True>,
#  <Conv2D name=Mixed_6a_Branch_1_Conv2d_0b_3x3, built=True>,
#  <BatchNormalization name=Mixed_6a_Branch_1_Conv2d_0b_3x3_BatchNorm, built=True>,
#  <Activation name=Mixed_6a_Branch_1_Conv2d_0b_3x3_Activation, built=True>,
#  <Conv2D name=Mixed_6a_Branch_0_Conv2d_1a_3x3, built=True>,
#  <Conv2D name=Mixed_6a_Branch_1_Conv2d_1a_3x3, built=True>,
#  <BatchNormalization name=Mixed_6a_Branch_0_Conv2d_1a_3x3_BatchNorm, built=True>,
#  <BatchNormalization name=Mixed_6a_Branch_1_Conv2d_1a_3x3_BatchNorm, built=True>,
#  <Activation name=Mixed_6a_Branch_0_Conv2d_1a_3x3_Activation, built=True>,
#  <Activation name=Mixed_6a_Branch_1_Conv2d_1a_3x3_Activation, built=True>,
#  <MaxPooling2D name=Mixed_6a_Branch_2_MaxPool_1a_3x3, built=True>,
#  <Concatenate name=Mixed_6a, built=True>,
#  <Conv2D name=Block17_1_Branch_1_Conv2d_0a_1x1, built=True>,
#  <BatchNormalization name=Block17_1_Branch_1_Conv2d_0a_1x1_BatchNorm, built=True>,
#  <Activation name=Block17_1_Branch_1_Conv2d_0a_1x1_Activation, built=True>,
#  <Conv2D name=Block17_1_Branch_1_Conv2d_0b_1x7, built=True>,
#  <BatchNormalization name=Block17_1_Branch_1_Conv2d_0b_1x7_BatchNorm, built=True>,
#  <Activation name=Block17_1_Branch_1_Conv2d_0b_1x7_Activation, built=True>,
#  <Conv2D name=Block17_1_Branch_0_Conv2d_1x1, built=True>,
#  <Conv2D name=Block17_1_Branch_1_Conv2d_0c_7x1, built=True>,
#  <BatchNormalization name=Block17_1_Branch_0_Conv2d_1x1_BatchNorm, built=True>,
#  <BatchNormalization name=Block17_1_Branch_1_Conv2d_0c_7x1_BatchNorm, built=True>,
#  <Activation name=Block17_1_Branch_0_Conv2d_1x1_Activation, built=True>,
#  <Activation name=Block17_1_Branch_1_Conv2d_0c_7x1_Activation, built=True>,
#  <Concatenate name=Block17_1_Concatenate, built=True>,
#  <Conv2D name=Block17_1_Conv2d_1x1, built=True>,
#  <Lambda name=lambda_5, built=True>,
#  <Add name=add_5, built=True>,
#  <Activation name=Block17_1_Activation, built=True>,
#  <Conv2D name=Block17_2_Branch_1_Conv2d_0a_1x1, built=True>,
#  <BatchNormalization name=Block17_2_Branch_1_Conv2d_0a_1x1_BatchNorm, built=True>,
#  <Activation name=Block17_2_Branch_1_Conv2d_0a_1x1_Activation, built=True>,
#  <Conv2D name=Block17_2_Branch_1_Conv2d_0b_1x7, built=True>,
#  <BatchNormalization name=Block17_2_Branch_1_Conv2d_0b_1x7_BatchNorm, built=True>,
#  <Activation name=Block17_2_Branch_1_Conv2d_0b_1x7_Activation, built=True>,
#  <Conv2D name=Block17_2_Branch_0_Conv2d_1x1, built=True>,
#  <Conv2D name=Block17_2_Branch_1_Conv2d_0c_7x1, built=True>,
#  <BatchNormalization name=Block17_2_Branch_0_Conv2d_1x1_BatchNorm, built=True>,
#  <BatchNormalization name=Block17_2_Branch_1_Conv2d_0c_7x1_BatchNorm, built=True>,
#  <Activation name=Block17_2_Branch_0_Conv2d_1x1_Activation, built=True>,
#  <Activation name=Block17_2_Branch_1_Conv2d_0c_7x1_Activation, built=True>,
#  <Concatenate name=Block17_2_Concatenate, built=True>,
#  <Conv2D name=Block17_2_Conv2d_1x1, built=True>,
#  <Lambda name=lambda_6, built=True>,
#  <Add name=add_6, built=True>,
#  <Activation name=Block17_2_Activation, built=True>,
#  <Conv2D name=Block17_3_Branch_1_Conv2d_0a_1x1, built=True>,
#  <BatchNormalization name=Block17_3_Branch_1_Conv2d_0a_1x1_BatchNorm, built=True>,
#  <Activation name=Block17_3_Branch_1_Conv2d_0a_1x1_Activation, built=True>,
#  <Conv2D name=Block17_3_Branch_1_Conv2d_0b_1x7, built=True>,
#  <BatchNormalization name=Block17_3_Branch_1_Conv2d_0b_1x7_BatchNorm, built=True>,
#  <Activation name=Block17_3_Branch_1_Conv2d_0b_1x7_Activation, built=True>,
#  <Conv2D name=Block17_3_Branch_0_Conv2d_1x1, built=True>,
#  <Conv2D name=Block17_3_Branch_1_Conv2d_0c_7x1, built=True>,
#  <BatchNormalization name=Block17_3_Branch_0_Conv2d_1x1_BatchNorm, built=True>,
#  <BatchNormalization name=Block17_3_Branch_1_Conv2d_0c_7x1_BatchNorm, built=True>,
#  <Activation name=Block17_3_Branch_0_Conv2d_1x1_Activation, built=True>,
#  <Activation name=Block17_3_Branch_1_Conv2d_0c_7x1_Activation, built=True>,
#  <Concatenate name=Block17_3_Concatenate, built=True>,
#  <Conv2D name=Block17_3_Conv2d_1x1, built=True>,
#  <Lambda name=lambda_7, built=True>,
#  <Add name=add_7, built=True>,
#  <Activation name=Block17_3_Activation, built=True>,
#  <Conv2D name=Block17_4_Branch_1_Conv2d_0a_1x1, built=True>,
#  <BatchNormalization name=Block17_4_Branch_1_Conv2d_0a_1x1_BatchNorm, built=True>,
#  <Activation name=Block17_4_Branch_1_Conv2d_0a_1x1_Activation, built=True>,
#  <Conv2D name=Block17_4_Branch_1_Conv2d_0b_1x7, built=True>,
#  <BatchNormalization name=Block17_4_Branch_1_Conv2d_0b_1x7_BatchNorm, built=True>,
#  <Activation name=Block17_4_Branch_1_Conv2d_0b_1x7_Activation, built=True>,
#  <Conv2D name=Block17_4_Branch_0_Conv2d_1x1, built=True>,
#  <Conv2D name=Block17_4_Branch_1_Conv2d_0c_7x1, built=True>,
#  <BatchNormalization name=Block17_4_Branch_0_Conv2d_1x1_BatchNorm, built=True>,
#  <BatchNormalization name=Block17_4_Branch_1_Conv2d_0c_7x1_BatchNorm, built=True>,
#  <Activation name=Block17_4_Branch_0_Conv2d_1x1_Activation, built=True>,
#  <Activation name=Block17_4_Branch_1_Conv2d_0c_7x1_Activation, built=True>,
#  <Concatenate name=Block17_4_Concatenate, built=True>,
#  <Conv2D name=Block17_4_Conv2d_1x1, built=True>,
#  <Lambda name=lambda_8, built=True>,
#  <Add name=add_8, built=True>,
#  <Activation name=Block17_4_Activation, built=True>,
#  <Conv2D name=Block17_5_Branch_1_Conv2d_0a_1x1, built=True>,
#  <BatchNormalization name=Block17_5_Branch_1_Conv2d_0a_1x1_BatchNorm, built=True>,
#  <Activation name=Block17_5_Branch_1_Conv2d_0a_1x1_Activation, built=True>,
#  <Conv2D name=Block17_5_Branch_1_Conv2d_0b_1x7, built=True>,
#  <BatchNormalization name=Block17_5_Branch_1_Conv2d_0b_1x7_BatchNorm, built=True>,
#  <Activation name=Block17_5_Branch_1_Conv2d_0b_1x7_Activation, built=True>,
#  <Conv2D name=Block17_5_Branch_0_Conv2d_1x1, built=True>,
#  <Conv2D name=Block17_5_Branch_1_Conv2d_0c_7x1, built=True>,
#  <BatchNormalization name=Block17_5_Branch_0_Conv2d_1x1_BatchNorm, built=True>,
#  <BatchNormalization name=Block17_5_Branch_1_Conv2d_0c_7x1_BatchNorm, built=True>,
#  <Activation name=Block17_5_Branch_0_Conv2d_1x1_Activation, built=True>,
#  <Activation name=Block17_5_Branch_1_Conv2d_0c_7x1_Activation, built=True>,
#  <Concatenate name=Block17_5_Concatenate, built=True>,
#  <Conv2D name=Block17_5_Conv2d_1x1, built=True>,
#  <Lambda name=lambda_9, built=True>,
#  <Add name=add_9, built=True>,
#  <Activation name=Block17_5_Activation, built=True>,
#  <Conv2D name=Block17_6_Branch_1_Conv2d_0a_1x1, built=True>,
#  <BatchNormalization name=Block17_6_Branch_1_Conv2d_0a_1x1_BatchNorm, built=True>,
#  <Activation name=Block17_6_Branch_1_Conv2d_0a_1x1_Activation, built=True>,
#  <Conv2D name=Block17_6_Branch_1_Conv2d_0b_1x7, built=True>,
#  <BatchNormalization name=Block17_6_Branch_1_Conv2d_0b_1x7_BatchNorm, built=True>,
#  <Activation name=Block17_6_Branch_1_Conv2d_0b_1x7_Activation, built=True>,
#  <Conv2D name=Block17_6_Branch_0_Conv2d_1x1, built=True>,
#  <Conv2D name=Block17_6_Branch_1_Conv2d_0c_7x1, built=True>,
#  <BatchNormalization name=Block17_6_Branch_0_Conv2d_1x1_BatchNorm, built=True>,
#  <BatchNormalization name=Block17_6_Branch_1_Conv2d_0c_7x1_BatchNorm, built=True>,
#  <Activation name=Block17_6_Branch_0_Conv2d_1x1_Activation, built=True>,
#  <Activation name=Block17_6_Branch_1_Conv2d_0c_7x1_Activation, built=True>,
#  <Concatenate name=Block17_6_Concatenate, built=True>,
#  <Conv2D name=Block17_6_Conv2d_1x1, built=True>,
#  <Lambda name=lambda_10, built=True>,
#  <Add name=add_10, built=True>,
#  <Activation name=Block17_6_Activation, built=True>,
#  <Conv2D name=Block17_7_Branch_1_Conv2d_0a_1x1, built=True>,
#  <BatchNormalization name=Block17_7_Branch_1_Conv2d_0a_1x1_BatchNorm, built=True>,
#  <Activation name=Block17_7_Branch_1_Conv2d_0a_1x1_Activation, built=True>,
#  <Conv2D name=Block17_7_Branch_1_Conv2d_0b_1x7, built=True>,
#  <BatchNormalization name=Block17_7_Branch_1_Conv2d_0b_1x7_BatchNorm, built=True>,
#  <Activation name=Block17_7_Branch_1_Conv2d_0b_1x7_Activation, built=True>,
#  <Conv2D name=Block17_7_Branch_0_Conv2d_1x1, built=True>,
#  <Conv2D name=Block17_7_Branch_1_Conv2d_0c_7x1, built=True>,
#  <BatchNormalization name=Block17_7_Branch_0_Conv2d_1x1_BatchNorm, built=True>,
#  <BatchNormalization name=Block17_7_Branch_1_Conv2d_0c_7x1_BatchNorm, built=True>,
#  <Activation name=Block17_7_Branch_0_Conv2d_1x1_Activation, built=True>,
#  <Activation name=Block17_7_Branch_1_Conv2d_0c_7x1_Activation, built=True>,
#  <Concatenate name=Block17_7_Concatenate, built=True>,
#  <Conv2D name=Block17_7_Conv2d_1x1, built=True>,
#  <Lambda name=lambda_11, built=True>,
#  <Add name=add_11, built=True>,
#  <Activation name=Block17_7_Activation, built=True>,
#  <Conv2D name=Block17_8_Branch_1_Conv2d_0a_1x1, built=True>,
#  <BatchNormalization name=Block17_8_Branch_1_Conv2d_0a_1x1_BatchNorm, built=True>,
#  <Activation name=Block17_8_Branch_1_Conv2d_0a_1x1_Activation, built=True>,
#  <Conv2D name=Block17_8_Branch_1_Conv2d_0b_1x7, built=True>,
#  <BatchNormalization name=Block17_8_Branch_1_Conv2d_0b_1x7_BatchNorm, built=True>,
#  <Activation name=Block17_8_Branch_1_Conv2d_0b_1x7_Activation, built=True>,
#  <Conv2D name=Block17_8_Branch_0_Conv2d_1x1, built=True>,
#  <Conv2D name=Block17_8_Branch_1_Conv2d_0c_7x1, built=True>,
#  <BatchNormalization name=Block17_8_Branch_0_Conv2d_1x1_BatchNorm, built=True>,
#  <BatchNormalization name=Block17_8_Branch_1_Conv2d_0c_7x1_BatchNorm, built=True>,
#  <Activation name=Block17_8_Branch_0_Conv2d_1x1_Activation, built=True>,
#  <Activation name=Block17_8_Branch_1_Conv2d_0c_7x1_Activation, built=True>,
#  <Concatenate name=Block17_8_Concatenate, built=True>,
#  <Conv2D name=Block17_8_Conv2d_1x1, built=True>,
#  <Lambda name=lambda_12, built=True>,
#  <Add name=add_12, built=True>,
#  <Activation name=Block17_8_Activation, built=True>,
#  <Conv2D name=Block17_9_Branch_1_Conv2d_0a_1x1, built=True>,
#  <BatchNormalization name=Block17_9_Branch_1_Conv2d_0a_1x1_BatchNorm, built=True>,
#  <Activation name=Block17_9_Branch_1_Conv2d_0a_1x1_Activation, built=True>,
#  <Conv2D name=Block17_9_Branch_1_Conv2d_0b_1x7, built=True>,
#  <BatchNormalization name=Block17_9_Branch_1_Conv2d_0b_1x7_BatchNorm, built=True>,
#  <Activation name=Block17_9_Branch_1_Conv2d_0b_1x7_Activation, built=True>,
#  <Conv2D name=Block17_9_Branch_0_Conv2d_1x1, built=True>,
#  <Conv2D name=Block17_9_Branch_1_Conv2d_0c_7x1, built=True>,
#  <BatchNormalization name=Block17_9_Branch_0_Conv2d_1x1_BatchNorm, built=True>,
#  <BatchNormalization name=Block17_9_Branch_1_Conv2d_0c_7x1_BatchNorm, built=True>,
#  <Activation name=Block17_9_Branch_0_Conv2d_1x1_Activation, built=True>,
#  <Activation name=Block17_9_Branch_1_Conv2d_0c_7x1_Activation, built=True>,
#  <Concatenate name=Block17_9_Concatenate, built=True>,
#  <Conv2D name=Block17_9_Conv2d_1x1, built=True>,
#  <Lambda name=lambda_13, built=True>,
#  <Add name=add_13, built=True>,
#  <Activation name=Block17_9_Activation, built=True>,
#  <Conv2D name=Block17_10_Branch_1_Conv2d_0a_1x1, built=True>,
#  <BatchNormalization name=Block17_10_Branch_1_Conv2d_0a_1x1_BatchNorm, built=True>,
#  <Activation name=Block17_10_Branch_1_Conv2d_0a_1x1_Activation, built=True>,
#  <Conv2D name=Block17_10_Branch_1_Conv2d_0b_1x7, built=True>,
#  <BatchNormalization name=Block17_10_Branch_1_Conv2d_0b_1x7_BatchNorm, built=True>,
#  <Activation name=Block17_10_Branch_1_Conv2d_0b_1x7_Activation, built=True>,
#  <Conv2D name=Block17_10_Branch_0_Conv2d_1x1, built=True>,
#  <Conv2D name=Block17_10_Branch_1_Conv2d_0c_7x1, built=True>,
#  <BatchNormalization name=Block17_10_Branch_0_Conv2d_1x1_BatchNorm, built=True>,
#  <BatchNormalization name=Block17_10_Branch_1_Conv2d_0c_7x1_BatchNorm, built=True>,
#  <Activation name=Block17_10_Branch_0_Conv2d_1x1_Activation, built=True>,
#  <Activation name=Block17_10_Branch_1_Conv2d_0c_7x1_Activation, built=True>,
#  <Concatenate name=Block17_10_Concatenate, built=True>,
#  <Conv2D name=Block17_10_Conv2d_1x1, built=True>,
#  <Lambda name=lambda_14, built=True>,
#  <Add name=add_14, built=True>,
#  <Activation name=Block17_10_Activation, built=True>,
#  <Conv2D name=Mixed_7a_Branch_2_Conv2d_0a_1x1, built=True>,
#  <BatchNormalization name=Mixed_7a_Branch_2_Conv2d_0a_1x1_BatchNorm, built=True>,
#  <Activation name=Mixed_7a_Branch_2_Conv2d_0a_1x1_Activation, built=True>,
#  <Conv2D name=Mixed_7a_Branch_0_Conv2d_0a_1x1, built=True>,
#  <Conv2D name=Mixed_7a_Branch_1_Conv2d_0a_1x1, built=True>,
#  <Conv2D name=Mixed_7a_Branch_2_Conv2d_0b_3x3, built=True>,
#  <BatchNormalization name=Mixed_7a_Branch_0_Conv2d_0a_1x1_BatchNorm, built=True>,
#  <BatchNormalization name=Mixed_7a_Branch_1_Conv2d_0a_1x1_BatchNorm, built=True>,
#  <BatchNormalization name=Mixed_7a_Branch_2_Conv2d_0b_3x3_BatchNorm, built=True>,
#  <Activation name=Mixed_7a_Branch_0_Conv2d_0a_1x1_Activation, built=True>,
#  <Activation name=Mixed_7a_Branch_1_Conv2d_0a_1x1_Activation, built=True>,
#  <Activation name=Mixed_7a_Branch_2_Conv2d_0b_3x3_Activation, built=True>,
#  <Conv2D name=Mixed_7a_Branch_0_Conv2d_1a_3x3, built=True>,
#  <Conv2D name=Mixed_7a_Branch_1_Conv2d_1a_3x3, built=True>,
#  <Conv2D name=Mixed_7a_Branch_2_Conv2d_1a_3x3, built=True>,
#  <BatchNormalization name=Mixed_7a_Branch_0_Conv2d_1a_3x3_BatchNorm, built=True>,
#  <BatchNormalization name=Mixed_7a_Branch_1_Conv2d_1a_3x3_BatchNorm, built=True>,
#  <BatchNormalization name=Mixed_7a_Branch_2_Conv2d_1a_3x3_BatchNorm, built=True>,
#  <Activation name=Mixed_7a_Branch_0_Conv2d_1a_3x3_Activation, built=True>,
#  <Activation name=Mixed_7a_Branch_1_Conv2d_1a_3x3_Activation, built=True>,
#  <Activation name=Mixed_7a_Branch_2_Conv2d_1a_3x3_Activation, built=True>,
#  <MaxPooling2D name=Mixed_7a_Branch_3_MaxPool_1a_3x3, built=True>,
#  <Concatenate name=Mixed_7a, built=True>,
#  <Conv2D name=Block8_1_Branch_1_Conv2d_0a_1x1, built=True>,
#  <BatchNormalization name=Block8_1_Branch_1_Conv2d_0a_1x1_BatchNorm, built=True>,
#  <Activation name=Block8_1_Branch_1_Conv2d_0a_1x1_Activation, built=True>,
#  <Conv2D name=Block8_1_Branch_1_Conv2d_0b_1x3, built=True>,
#  <BatchNormalization name=Block8_1_Branch_1_Conv2d_0b_1x3_BatchNorm, built=True>,
#  <Activation name=Block8_1_Branch_1_Conv2d_0b_1x3_Activation, built=True>,
#  <Conv2D name=Block8_1_Branch_0_Conv2d_1x1, built=True>,
#  <Conv2D name=Block8_1_Branch_1_Conv2d_0c_3x1, built=True>,
#  <BatchNormalization name=Block8_1_Branch_0_Conv2d_1x1_BatchNorm, built=True>,
#  <BatchNormalization name=Block8_1_Branch_1_Conv2d_0c_3x1_BatchNorm, built=True>,
#  <Activation name=Block8_1_Branch_0_Conv2d_1x1_Activation, built=True>,
#  <Activation name=Block8_1_Branch_1_Conv2d_0c_3x1_Activation, built=True>,
#  <Concatenate name=Block8_1_Concatenate, built=True>,
#  <Conv2D name=Block8_1_Conv2d_1x1, built=True>,
#  <Lambda name=lambda_15, built=True>,
#  <Add name=add_15, built=True>,
#  <Activation name=Block8_1_Activation, built=True>,
#  <Conv2D name=Block8_2_Branch_1_Conv2d_0a_1x1, built=True>,
#  <BatchNormalization name=Block8_2_Branch_1_Conv2d_0a_1x1_BatchNorm, built=True>,
#  <Activation name=Block8_2_Branch_1_Conv2d_0a_1x1_Activation, built=True>,
#  <Conv2D name=Block8_2_Branch_1_Conv2d_0b_1x3, built=True>,
#  <BatchNormalization name=Block8_2_Branch_1_Conv2d_0b_1x3_BatchNorm, built=True>,
#  <Activation name=Block8_2_Branch_1_Conv2d_0b_1x3_Activation, built=True>,
#  <Conv2D name=Block8_2_Branch_0_Conv2d_1x1, built=True>,
#  <Conv2D name=Block8_2_Branch_1_Conv2d_0c_3x1, built=True>,
#  <BatchNormalization name=Block8_2_Branch_0_Conv2d_1x1_BatchNorm, built=True>,
#  <BatchNormalization name=Block8_2_Branch_1_Conv2d_0c_3x1_BatchNorm, built=True>,
#  <Activation name=Block8_2_Branch_0_Conv2d_1x1_Activation, built=True>,
#  <Activation name=Block8_2_Branch_1_Conv2d_0c_3x1_Activation, built=True>,
#  <Concatenate name=Block8_2_Concatenate, built=True>,
#  <Conv2D name=Block8_2_Conv2d_1x1, built=True>,
#  <Lambda name=lambda_16, built=True>,
#  <Add name=add_16, built=True>,
#  <Activation name=Block8_2_Activation, built=True>,
#  <Conv2D name=Block8_3_Branch_1_Conv2d_0a_1x1, built=True>,
#  <BatchNormalization name=Block8_3_Branch_1_Conv2d_0a_1x1_BatchNorm, built=True>,
#  <Activation name=Block8_3_Branch_1_Conv2d_0a_1x1_Activation, built=True>,
#  <Conv2D name=Block8_3_Branch_1_Conv2d_0b_1x3, built=True>,
#  <BatchNormalization name=Block8_3_Branch_1_Conv2d_0b_1x3_BatchNorm, built=True>,
#  <Activation name=Block8_3_Branch_1_Conv2d_0b_1x3_Activation, built=True>,
#  <Conv2D name=Block8_3_Branch_0_Conv2d_1x1, built=True>,
#  <Conv2D name=Block8_3_Branch_1_Conv2d_0c_3x1, built=True>,
#  <BatchNormalization name=Block8_3_Branch_0_Conv2d_1x1_BatchNorm, built=True>,
#  <BatchNormalization name=Block8_3_Branch_1_Conv2d_0c_3x1_BatchNorm, built=True>,
#  <Activation name=Block8_3_Branch_0_Conv2d_1x1_Activation, built=True>,
#  <Activation name=Block8_3_Branch_1_Conv2d_0c_3x1_Activation, built=True>,
#  <Concatenate name=Block8_3_Concatenate, built=True>,
#  <Conv2D name=Block8_3_Conv2d_1x1, built=True>,
#  <Lambda name=lambda_17, built=True>,
#  <Add name=add_17, built=True>,
#  <Activation name=Block8_3_Activation, built=True>,
#  <Conv2D name=Block8_4_Branch_1_Conv2d_0a_1x1, built=True>,
#  <BatchNormalization name=Block8_4_Branch_1_Conv2d_0a_1x1_BatchNorm, built=True>,
#  <Activation name=Block8_4_Branch_1_Conv2d_0a_1x1_Activation, built=True>,
#  <Conv2D name=Block8_4_Branch_1_Conv2d_0b_1x3, built=True>,
#  <BatchNormalization name=Block8_4_Branch_1_Conv2d_0b_1x3_BatchNorm, built=True>,
#  <Activation name=Block8_4_Branch_1_Conv2d_0b_1x3_Activation, built=True>,
#  <Conv2D name=Block8_4_Branch_0_Conv2d_1x1, built=True>,
#  <Conv2D name=Block8_4_Branch_1_Conv2d_0c_3x1, built=True>,
#  <BatchNormalization name=Block8_4_Branch_0_Conv2d_1x1_BatchNorm, built=True>,
#  <BatchNormalization name=Block8_4_Branch_1_Conv2d_0c_3x1_BatchNorm, built=True>,
#  <Activation name=Block8_4_Branch_0_Conv2d_1x1_Activation, built=True>,
#  <Activation name=Block8_4_Branch_1_Conv2d_0c_3x1_Activation, built=True>,
#  <Concatenate name=Block8_4_Concatenate, built=True>,
#  <Conv2D name=Block8_4_Conv2d_1x1, built=True>,
#  <Lambda name=lambda_18, built=True>,
#  <Add name=add_18, built=True>,
#  <Activation name=Block8_4_Activation, built=True>,
#  <Conv2D name=Block8_5_Branch_1_Conv2d_0a_1x1, built=True>,
#  <BatchNormalization name=Block8_5_Branch_1_Conv2d_0a_1x1_BatchNorm, built=True>,
#  <Activation name=Block8_5_Branch_1_Conv2d_0a_1x1_Activation, built=True>,
#  <Conv2D name=Block8_5_Branch_1_Conv2d_0b_1x3, built=True>,
#  <BatchNormalization name=Block8_5_Branch_1_Conv2d_0b_1x3_BatchNorm, built=True>,
#  <Activation name=Block8_5_Branch_1_Conv2d_0b_1x3_Activation, built=True>,
#  <Conv2D name=Block8_5_Branch_0_Conv2d_1x1, built=True>,
#  <Conv2D name=Block8_5_Branch_1_Conv2d_0c_3x1, built=True>,
#  <BatchNormalization name=Block8_5_Branch_0_Conv2d_1x1_BatchNorm, built=True>,
#  <BatchNormalization name=Block8_5_Branch_1_Conv2d_0c_3x1_BatchNorm, built=True>,
#  <Activation name=Block8_5_Branch_0_Conv2d_1x1_Activation, built=True>,
#  <Activation name=Block8_5_Branch_1_Conv2d_0c_3x1_Activation, built=True>,
#  <Concatenate name=Block8_5_Concatenate, built=True>,
#  <Conv2D name=Block8_5_Conv2d_1x1, built=True>,
#  <Lambda name=lambda_19, built=True>,
#  <Add name=add_19, built=True>,
#  <Activation name=Block8_5_Activation, built=True>,
#  <Conv2D name=Block8_6_Branch_1_Conv2d_0a_1x1, built=True>,
#  <BatchNormalization name=Block8_6_Branch_1_Conv2d_0a_1x1_BatchNorm, built=True>,
#  <Activation name=Block8_6_Branch_1_Conv2d_0a_1x1_Activation, built=True>,
#  <Conv2D name=Block8_6_Branch_1_Conv2d_0b_1x3, built=True>,
#  <BatchNormalization name=Block8_6_Branch_1_Conv2d_0b_1x3_BatchNorm, built=True>,
#  <Activation name=Block8_6_Branch_1_Conv2d_0b_1x3_Activation, built=True>,
#  <Conv2D name=Block8_6_Branch_0_Conv2d_1x1, built=True>,
#  <Conv2D name=Block8_6_Branch_1_Conv2d_0c_3x1, built=True>,
#  <BatchNormalization name=Block8_6_Branch_0_Conv2d_1x1_BatchNorm, built=True>,
#  <BatchNormalization name=Block8_6_Branch_1_Conv2d_0c_3x1_BatchNorm, built=True>,
#  <Activation name=Block8_6_Branch_0_Conv2d_1x1_Activation, built=True>,
#  <Activation name=Block8_6_Branch_1_Conv2d_0c_3x1_Activation, built=True>,
#  <Concatenate name=Block8_6_Concatenate, built=True>,
#  <Conv2D name=Block8_6_Conv2d_1x1, built=True>,
#  <Lambda name=lambda_20, built=True>,
#  <Add name=add_20, built=True>,
#  <GlobalAveragePooling2D name=AvgPool, built=True>,
#  <Dropout name=Dropout, built=True>,
#  <Dense name=Bottleneck, built=True>,
#  <BatchNormalization name=Bottleneck_BatchNorm, built=True>]

# %%
## FaceNet 전체 레이어 가중치 업데이트 방지
for l in facenet_model.layers :
    l.trainable = False

# %% [markdown]
# ### (2) 모델 구조 변형

# %% [markdown]
# * **세부 요구사항**
#     - 우리의 문제에 맞게 모델을 변형해야 합니다.
#     - 예시 코드에서 사용한 라이브러리
#         - keras

# %% [markdown]
# #### 1) 추가 모델링

# %%
# facenet + 이진 분류 layer
K.clear_session()

model_binary = keras.models.Sequential()

model_binary.add(facenet_model)
model_binary.add(keras.layers.Dense(1, activation='sigmoid'))

# %%
model_binary.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ inception_resnet_v1 (Functional)     │ (None, 128)                 │      22,808,144 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │             129 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 22,808,273 (87.01 MB)
#  Trainable params: 129 (516.00 B)
#  Non-trainable params: 22,808,144 (87.01 MB)

# %%
model_binary.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy', 'precision', 'recall'])

# %% [markdown]
# ## 5.미션3

# %% [markdown]
# 학습된 모델로 추론하여 성능 지표를 확인하고 모델을 개선시키세요.
#
# 그 후, 모델의 구조와 가중치를 **반드시 저장**하여 여러분의 노트북에 옮기세요.
#
# - 1) 다양한 모델을 사용해보세요.
#     - 모델에 정해진 정답은 없습니다.
#     - 성능 지표에서 무엇이 중요한지 깊게 생각하세요.
#     - 사전 학습된 FaceNet 모델을 사용하셔도 좋고, 아예 독창적으로 여러분만의 모델을 만드셔도 좋습니다!
# - 2) 모델을 **반드시 저장**하세요.
#     - .keras 형태로 우선 Colab에 저장하세요.
#     - Colab에 생성된 .keras 파일을 **로컬에 다운로드** 합니다.

# %% [markdown]
# ### (1) 모델 학습

# %% [markdown]
# * **세부 요구사항**
#     - 모델 구조를 잘 변형하였다면, 학습도 진행해야 합니다.
#         - Keras에서 지원하는 다양한 함수를 사용하세요.
#     - 예시 코드에서 사용한 라이브러리
#         - keras

# %% [markdown]
# #### 1) 학습에 유용한 함수 불러오기

# %%
from keras.callbacks import EarlyStopping

# %%
es = EarlyStopping(patience=4, verbose=1 ,restore_best_weights=True)

# %% [markdown]
# #### 2) 모델 학습

# %%
model_binary.fit(train_id_scaled,
                 validation_data=val_id_scaled,
                 epochs=5
                 )
# Out:
# Epoch 1/5
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 22s 53ms/step - accuracy: 0.9947 - loss: 0.0321 - precision: 0.9955 - recall: 0.9977 - val_accuracy: 0.9942 - val_loss: 0.0257 - val_precision: 0.9942 - val_recall: 0.9984
# Epoch 2/5
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 40s 51ms/step - accuracy: 0.9953 - loss: 0.0245 - precision: 0.9955 - recall: 0.9984 - val_accuracy: 0.9945 - val_loss: 0.0212 - val_precision: 0.9942 - val_recall: 0.9988
# Epoch 3/5
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 23s 57ms/step - accuracy: 0.9951 - loss: 0.0203 - precision: 0.9953 - recall: 0.9985 - val_accuracy: 0.9948 - val_loss: 0.0183 - val_precision: 0.9942 - val_recall: 0.9992
# Epoch 4/5
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 39s 54ms/step - accuracy: 0.9952 - loss: 0.0181 - precision: 0.9955 - recall: 0.9984 - val_accuracy: 0.9951 - val_loss: 0.0163 - val_precision: 0.9945 - val_recall: 0.9992
# Epoch 5/5
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 22s 55ms/step - accuracy: 0.9953 - loss: 0.0161 - precision: 0.9956 - recall: 0.9984 - val_accuracy: 0.9960 - val_loss: 0.0148 - val_precision: 0.9957 - val_recall: 0.9992

# %% [markdown]
# ### (2) 모델 추론

# %% [markdown]
# * **세부 요구사항**
#     - 학습된 모델의 성능을 확인해보세요.
#         - 임계값 조절, 클래스 가중치 부여 등으로 모델의 성능을 높여보세요.
#     - 예시 코드에서 사용한 라이브러리
#         - keras, sklearn

# %% [markdown]
# #### 1) 모델 추론

# %%
y_pred = model_binary.predict(test_id_scaled)
y_pred
# Out:
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 43ms/step
# array([[0.99748164],
#        [0.9986339 ],
#        [0.9996043 ],
#        ...,
#        [0.0010713 ],
#        [0.99997187],
#        [0.0021955 ]], dtype=float32)

# %%
y_pred_fix = np.where(y_pred > 0.5, 1, 0)
y_pred_fix = y_pred_fix.flatten()
y_pred_fix
# Out:
# array([1, 1, 1, ..., 0, 1, 0])

# %% [markdown]
# #### 2) 성능 확인

# %%
from sklearn.metrics import classification_report

# %%
tmp = []

for test_x, test_y in test_id_scaled:
    tmp.append(test_y.numpy())

y_true = np.concatenate(tmp)

# %%
len(y_true.nonzero()[0])
# Out:
# 2647

# %%
print(classification_report(y_true, y_pred_fix, target_names = ['me', 'others']))
# Out:
#               precision    recall  f1-score   support
#
#           me       0.23      0.23      0.23      1336
#       others       0.78      0.79      0.78      4743
#
#     accuracy                           0.66      6079
#    macro avg       0.51      0.51      0.51      6079
# weighted avg       0.66      0.66      0.66      6079

# %% [markdown]
# ### (3) 모델 저장

# %% [markdown]
# * **세부 요구사항**
#     - **반드시 반드시 모델을 저장하고 로컬에 다운로드하세요.**
#     - 예시 코드에서 사용한 라이브러리
#         - keras

# %% [markdown]
# #### 1) 모델 저장

# %%
## .keras로 저장해야 안전
model_binary.save('Facenet_binary2.keras')

# %% [markdown]
# #### 2) 저장된 모델 체크

# %%
## Colab에 저장된 모델을 불러와 확인
temp_model = keras.saving.load_model('/content/Facenet_binary2.keras')
temp_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ inception_resnet_v1 (Functional)     │ (None, 128)                 │      22,808,144 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │             129 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 22,808,533 (87.01 MB)
#  Trainable params: 129 (516.00 B)
#  Non-trainable params: 22,808,144 (87.01 MB)
#  Optimizer params: 260 (1.02 KB)
